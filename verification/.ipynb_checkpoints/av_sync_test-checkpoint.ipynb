# %%
from glob import glob
import os

# %%
experiment_no = 498
file_idx = 5
area = 'gily_center' # options are {"nest","center","gily_center","burrow"} - area of arena to check

path = f"/mnt/home/neurostatslab/ceph/saneslab_data/big_setup/experiment_{experiment_no}/concatenated_data_cam_mic_sync/"
sync_output = f"/mnt/home/neurostatslab/ceph/saneslab_data/big_setup/experiment_{experiment_no}/sync_test/"
os.makedirs(sync_output, exist_ok=True)

channel_dict = {"nest":[0],"burrow":[1],"center":[2],"gily_center":[4]}
vid_dict = {'center':'center',"nest":"nest_top","burrow":"burrow_side","gily_center":"gily_center"}

try:
    channels = channel_dict[area]
except:
    raise Exception("invalid area input")

audio = None
for ch in channels: 
    str_1 = "%02d"%(ch)
    str_2 = "%03d"%(file_idx)
    # getting the files
    audio_file = glob(path+f"channel_{str_1}_file_{str_2}.wav")[0]

str_1 = vid_dict[area]
str_2 = "%03d"%(file_idx)
# getting the video file
video_file = glob(path+f"video_{str_1}_{str_2}.mp4")[0]

# %% [markdown]
# ### For FFMPEG, use the miniforge env ffmpeg-env

# %%
import subprocess
output_path = f"{sync_output}av_{area}_file_{str_2}.mp4"

subprocess.run([
    "ffmpeg",
    "-i", video_file,
    "-i", audio_file,
    "-c:v", "copy",
    "-c:a", "aac",
    output_path
])
# Out:
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 12.3.0 (conda-forge gcc 12.3.0-2)
#   configuration: --prefix=/mnt/home/njoseph/miniforge3/envs/common --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1696213708285/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1696213708285/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1696213708285/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1696213708285/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1696213708285/_build_env/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/mnt/home/neurostatslab/ceph/saneslab_data/big_setup/experiment_498/concatenated_data_cam_mic_sync/video_gily_center_005.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf62.3.100
#   Duration: 00:06:00.00, start: 0.000000, bitrate: 4707 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, 4704 kb/s, 30 fps, 30 tbr, 1000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Input #1, wav, from '/mnt/home/neurostatslab/ceph/saneslab_data/big_setup/experiment_498/concatenated_data_cam_mic_sync/channel_04_file_005.wav':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Duration: 00:06:00.00, bitrate: 4000 kb/s
#   Stream #1:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (pcm_f32le (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to '/mnt/home/neurostatslab/ceph/saneslab_data/big_setup/experiment_498/sync_test/av_gily_center_file_005.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1600x1200, q=2-31, 4704 kb/s, 30 fps, 30 tbr, 1000k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 96000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc59.37.100 aac
# frame=10800 fps=1967 q=-1.0 Lsize=  210175kB time=00:06:00.00 bitrate=4782.7kbits/s speed=65.6x
# video:206721kB audio:3079kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.179032%
# [aac @ 0x555555644180] Qavg: 224.524
# CompletedProcess(args=['ffmpeg', '-i', '/mnt/home/neurostatslab/ceph/saneslab_data/big_setup/experiment_498/concatenated_data_cam_mic_sync/video_gily_center_005.mp4', '-i', '/mnt/home/neurostatslab/ceph/saneslab_data/big_setup/experiment_498/concatenated_data_cam_mic_sync/channel_04_file_005.wav', '-c:v', 'copy', '-c:a', 'aac', '/mnt/home/neurostatslab/ceph/saneslab_data/big_setup/experiment_498/sync_test/av_gily_center_file_005.mp4'], returncode=0)

# %% [markdown]
# ### For Moviepy, use the miniforge env analysis

# %%
# from moviepy import VideoFileClip, AudioFileClip

# %%
# audio = AudioFileClip(audio_file)
# video = VideoFileClip(video_file)

# final = video.with_audio(audio)  # note: set_audio() is now with_audio() in v2

# final.write_videofile(sync_output+f"av_{area}_file_{str_2}.mp4",codec="libx264",audio_codec="aac",preset="ultrafast")
