# %% [markdown]
# ### Note: Please ensure that this notebook is run in the daq environment

# %%
import glob
import os
import tqdm
from collections import defaultdict
import re
import numpy as np
import pandas as pd
from scipy.io import wavfile
# from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.video.io.VideoFileClip import VideoFileClip
from datetime import datetime, timedelta

# %%
# def seconds_to_hms(seconds):
#     # Calculate hours, minutes, and seconds
#     hours, remainder = divmod(seconds, 3600)
#     minutes, seconds = divmod(remainder, 60)
#     # Format the time in HH:MM:SS
#     return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02}.{int(remainder%1*1000):03}"

# %%
from moviepy.tools import subprocess_call
from moviepy.config import get_setting

# def ffmpeg_extract_subclip(filename, t1, t2, targetname=None):
def ffmpeg_extract_subclip(filename, start_frame, end_frame, targetname=None):
    """ Makes a new video file playing video file ``filename`` between
    the times ``t1`` and ``t2``. """
    # !ffmpeg -i {filename} -ss {seconds_to_hms(t1)} -to {seconds_to_hms(t2)} -c copy {targetname}
    tmp_str = f"between(n\,{start_frame}\,{end_frame}),setpts=PTS-STARTPTS"
    # !ffmpeg -i {filename} -vf select={tmp_str} -c:v libx264 -crf 0 {targetname}

# %%
experiment_no = 530
no_channels = 14
camera_fps = 30
# camera_corrected_sample_time = 0.03338542
file_length = 360 # in seconds (360 sec - 6 mins)
# nidaq_folder = "D:/big_setup/experiment_{}/nidaq/".format(experiment_no)
nidaq_folder = "D:/big_setup/experiment_{}/nidaq/".format(experiment_no)
video_folder = "D:/big_setup/experiment_{}/videos/".format(experiment_no)

# %%
# Deleting the trunc files if it is already present
trunc_files = glob.glob(nidaq_folder+"*_trunc*")
for i in trunc_files:
    os.remove(i) 

trunc_files = glob.glob(video_folder+"*_trunc*")
for i in trunc_files:
    os.remove(i)

# %%
nidaq_files = glob.glob(nidaq_folder+"*")
video_files = glob.glob(video_folder+"*")

# %%
# Creating separate folders for the concatenated data
path_concat = "D:/big_setup/experiment_{}/concatenated_data_cam_mic_sync/temp/".format(experiment_no)

try:
    os.makedirs(path_concat)
except:
    pass

# %%
path_final = "D:/big_setup/experiment_{}/concatenated_data_cam_mic_sync/".format(experiment_no)

# %%
# Functions to sort file names correctly
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
nidaq_files.sort(key=natural_keys)
video_files.sort(key=natural_keys)

# %%
nidaq_files = [i.replace("\\",'/') for i in nidaq_files]
video_files = [i.replace("\\",'/') for i in video_files]

# %% [markdown]
# ### For Videos

# %%
# Getting the camera names
temp_cam_name = []
for i in video_files:
    temp_cam_name.append(i.split("/")[-1].split("-")[0])
camera_names = list(set(temp_cam_name))
print(camera_names)
# Out:
# ['center', 'nest_side', 'burrow_side', 'nest_other_side', 'nest_top', 'gily_center', 'burrow_top']

# %%
# Creating a dictionary of all videos of a single camera
video_by_camera = defaultdict(lambda:[])
for idx,name in enumerate(temp_cam_name):
    video_by_camera[name].append(video_files[idx])

# %%
cam_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")

# %%
file_breaks  = np.arange(0,cam_clk_data.tail(1).index[0]/camera_fps,file_length)
timestamp_idx = []
for val in file_breaks:
    timestamp_idx.append((np.abs(cam_clk_data[f'concat_{camera_names[0]}_time_from_vid_start'] - val)).argmin())

# %%
for cam in camera_names:
    file_break_idx = 1
    file_concat_index = 0 
    str_1 = "%03d"%(file_concat_index)
    filename_txt = path_concat + f"video_{cam}_{str_1}.txt"
    f = open(filename_txt, 'w')
    no_videos = len(video_by_camera[cam])

    for index, vid_name in enumerate(video_by_camera[cam]):


        try:
            temp = cam_clk_data.iloc[timestamp_idx[file_break_idx]][f'{cam}_file_name'].split('\\')
        except:
            print("Index from timestamp not found")
            pass
        
        if temp[0]+'/'+temp[1] == vid_name and index != no_videos -1 :
            #break_time = cam_clk_data.iloc[timestamp_idx[file_break_idx]][f'{cam}_time_from_vid_start']
            break_frame = cam_clk_data.iloc[timestamp_idx[file_break_idx]][f'{cam}_frame_idx']
            target_file = temp[0]+"/"+temp[1].split(".")[0]+"_trunc_0.mp4"
            ffmpeg_extract_subclip(vid_name, 0, break_frame, targetname=target_file)
            
            # with VideoFileClip(vid_name) as video:
            #     new = video.subclip(0.0, break_time)
            #     new.write_videofile(target_file, audio_codec='aac')

            f.write("file \'{}\'\n".format(target_file))
            f.close()


            target_file = temp[0]+"/"+temp[1].split(".")[0]+"_trunc_1.mp4"
            with VideoFileClip(vid_name) as video:
                #end_time = video.duration
                end_frame = video.reader.nframes
                # new = video.subclip(break_time, end_time)
                # new.write_videofile(target_file, audio_codec='aac')
            ffmpeg_extract_subclip(vid_name, break_frame, end_frame, targetname=target_file)



            file_concat_index+=1
            file_break_idx+=1
            str_1 = "%03d"%(file_concat_index)
            filename_txt = path_concat + f"video_{cam}_{str_1}.txt"
            f = open(filename_txt, 'w')
            f.write("file \'{}\'\n".format(target_file))


        elif temp[0]+'/'+temp[1] != vid_name and index == no_videos -1:
            cam_stop_rec_video_name = cam_clk_data[f"{cam}_file_name"].iloc[-1]
            try:
                cam_stop_rec_frame = int(cam_clk_data[f"{cam}_frame_idx"].iloc[-1])
            except Exception as e: # trying to catch exceptions that arise when the video is not long enough (camera drop/frame drop)
                print(e)
                cam_stop_rec_frame = None
            
            target_file = vid_name.split(".")[0]+"_trunc_0.mp4"

            if cam_stop_rec_frame == None:
                target_file = cam_stop_rec_video_name
            else:
                ffmpeg_extract_subclip(cam_stop_rec_video_name, 0, cam_stop_rec_frame, targetname=target_file)
                
                # with VideoFileClip(cam_stop_rec_video_name) as video:
                #     new = video.subclip(0.0,(cam_stop_rec_frame+1)/camera_fps)
                #     new.write_videofile(target_file, audio_codec='aac')

            f.write("file \'{}\'\n".format(target_file))
            f.close()

        elif temp[0]+'/'+temp[1] == vid_name and index == no_videos -1:
            cam_stop_rec_video_name = cam_clk_data[f"{cam}_file_name"].iloc[-1]
            # cam_stop_rec_frame = int(cam_clk_data[f"{cam}_frame_idx"].iloc[-1])

            try:
                cam_stop_rec_frame = int(cam_clk_data[f"{cam}_frame_idx"].iloc[-1])
            except Exception as e: # trying to catch exceptions that arise when the video is not long enough (camera drop/frame drop)
                print(e)
                cam_stop_rec_frame = None

            #break_time = cam_clk_data.iloc[timestamp_idx[file_break_idx]][f'{cam}_time_from_vid_start']
            break_frame = cam_clk_data.iloc[timestamp_idx[file_break_idx]][f'{cam}_frame_idx']
            target_file = temp[0]+"/"+temp[1].split(".")[0]+"_trunc_0.mp4"
            if cam_stop_rec_frame == None:
                target_file = cam_stop_rec_video_name
            else:
                ffmpeg_extract_subclip(vid_name, 0, break_frame, targetname=target_file)
                # with VideoFileClip(vid_name) as video:
                #     new = video.subclip(0.0,break_time)
                #     new.write_videofile(target_file, audio_codec='aac')

            f.write("file \'{}\'\n".format(target_file))
            f.close()

            if cam_stop_rec_frame != None:
                target_file = temp[0]+"/"+temp[1].split(".")[0]+"_trunc_1.mp4"
                #end_time = (cam_stop_rec_frame+1)/camera_fps
                end_frame = cam_stop_rec_frame
                ffmpeg_extract_subclip(vid_name, break_frame, end_frame, targetname=target_file)
                # with VideoFileClip(vid_name) as video:
                #     new = video.subclip(break_time,end_time)
                #     new.write_videofile(target_file, audio_codec='aac')
                
                file_concat_index+=1
                str_1 = "%03d"%(file_concat_index)
                filename_txt = path_concat + f"video_{cam}_{str_1}.txt"
                f = open(filename_txt, 'w')
                f.write("file \'{}\'\n".format(target_file))
                f.close()

        elif index != no_videos -1:
            f.write("file \'{}\'\n".format(vid_name))
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 9.2.1 (GCC) 20200122
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libmfx --enable-amf --enable-ffnvcodec --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_530/videos/center-20260302T144637-145138.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 7696 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1600x1200, 7693 kb/s, 30 fps, 30 tbr, 10000k tbn, 20000k tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0000021d68fb9a00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0000021d68fb9a00] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0000021d68fb9a00] 64 - core 159 - H.264/MPEG-4 AVC codec - Copyleft 2003-2019 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_530/videos/center-20260302T144637-145138_trunc_0.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1600x1200, q=-1--1, 30 fps, 1000k tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   33 fps=0.0 q=0.0 size=    3840kB time=00:00:00.43 bitrate=72595.2kbits/s speed=0.858x
# frame=   56 fps= 56 q=0.0 size=    9728kB time=00:00:01.19 bitrate=66410.7kbits/s speed=1.19x
# frame=   81 fps= 51 q=0.0 size=   16128kB time=00:00:02.03 bitrate=64978.1kbits/s speed=1.28x
# frame=  111 fps= 50 q=0.0 size=   23808kB time=00:00:03.03 bitrate=64298.0kbits/s speed=1.38x
# frame=  140 fps= 51 q=0.0 size=   30976kB time=00:00:03.99 bitrate=63439.6kbits/s speed=1.47x
# frame=  163 fps= 50 q=0.0 size=   36864kB time=00:00:04.76 bitrate=63355.2kbits/s speed=1.47x
# frame=  190 fps= 51 q=0.0 size=   43776kB time=00:00:05.66 bitrate=63285.3kbits/s speed=1.51x
# frame=  213 fps= 50 q=0.0 size=   49664kB time=00:00:06.43 bitrate=63241.2kbits/s speed= 1.5x
# frame=  231 fps= 48 q=0.0 size=   54272kB time=00:00:07.03 bitrate=63213.4kbits/s speed=1.47x
# frame=  261 fps= 48 q=0.0 size=   61952kB time=00:00:08.03 bitrate=63176.3kbits/s speed=1.48x
# frame=  290 fps= 49 q=0.0 size=   69632kB time=00:00:08.99 bitrate=63381.3kbits/s speed=1.52x
# frame=  317 fps= 49 q=0.0 size=   76288kB time=00:00:09.89 bitrate=63127.1kbits/s speed=1.54x
# frame=  340 fps= 49 q=0.0 size=   82176kB time=00:00:10.66 bitrate=63111.8kbits/s speed=1.54x
# frame=  369 fps= 49 q=0.0 size=   89600kB time=00:00:11.63 bitrate=63095.5kbits/s speed=1.55x
# frame=  399 fps= 50 q=0.0 size=   97280kB time=00:00:12.63 bitrate=63081.2kbits/s speed=1.58x
# frame=  422 fps= 50 q=0.0 size=  103168kB time=00:00:13.39 bitrate=63071.7kbits/s speed=1.58x
# frame=  445 fps= 49 q=0.0 size=  109056kB time=00:00:14.16 bitrate=63063.2kbits/s speed=1.57x
# frame=  471 fps= 49 q=0.0 size=  115712kB time=00:00:15.03 bitrate=63054.7kbits/s speed=1.58x
# frame=  501 fps= 50 q=0.0 size=  123392kB time=00:00:16.03 bitrate=63046.0kbits/s speed=1.59x
# frame=  531 fps= 50 q=0.0 size=  131328kB time=00:00:17.03 bitrate=63161.5kbits/s speed= 1.6x
# frame=  561 fps= 50 q=0.0 size=  139008kB time=00:00:18.03 bitrate=63147.8kbits/s speed=1.61x
# frame=  591 fps= 50 q=0.0 size=  146688kB time=00:00:19.03 bitrate=63135.6kbits/s speed=1.62x
# frame=  621 fps= 51 q=0.0 size=  154368kB time=00:00:20.03 bitrate=63124.6kbits/s speed=1.63x
# frame=  651 fps= 51 q=0.0 size=  161792kB time=00:00:21.03 bitrate=63014.9kbits/s speed=1.64x
# frame=  681 fps= 51 q=0.0 size=  169472kB time=00:00:22.03 bitrate=63010.4kbits/s speed=1.65x
# frame=  711 fps= 51 q=0.0 size=  177152kB time=00:00:23.03 bitrate=63006.3kbits/s speed=1.66x
# frame=  741 fps= 51 q=0.0 size=  184832kB time=00:00:24.03 bitrate=63002.5kbits/s speed=1.66x
# frame=  770 fps= 51 q=0.0 size=  192000kB time=00:00:24.99 bitrate=62915.2kbits/s speed=1.67x
# frame=  797 fps= 51 q=0.0 size=  198656kB time=00:00:25.89 bitrate=62834.2kbits/s speed=1.67x
# frame=  822 fps= 51 q=0.0 size=  205312kB time=00:00:26.73 bitrate=62915.2kbits/s speed=1.67x
# frame=  850 fps= 51 q=0.0 size=  212480kB time=00:00:27.66 bitrate=62915.2kbits/s speed=1.67x
# frame=  879 fps= 52 q=0.0 size=  219904kB time=00:00:28.63 bitrate=62915.2kbits/s speed=1.68x
# frame=  907 fps= 52 q=0.0 size=  227328kB time=00:00:29.56 bitrate=62986.1kbits/s speed=1.68x
# frame=  931 fps= 52 q=0.0 size=  233472kB time=00:00:30.36 bitrate=62984.3kbits/s speed=1.68x
# frame=  958 fps= 52 q=0.0 size=  240384kB time=00:00:31.26 bitrate=62982.3kbits/s speed=1.68x
# frame=  982 fps= 51 q=0.0 size=  246528kB time=00:00:32.06 bitrate=62980.6kbits/s speed=1.68x
# frame= 1011 fps= 51 q=0.0 size=  253952kB time=00:00:33.03 bitrate=62978.7kbits/s speed=1.68x
# frame= 1041 fps= 51 q=0.0 size=  262144kB time=00:00:34.03 bitrate=63100.1kbits/s speed=1.68x
# frame= 1071 fps= 52 q=0.0 size=  269824kB time=00:00:35.03 bitrate=63094.8kbits/s speed=1.69x
# frame= 1101 fps= 52 q=0.0 size=  277504kB time=00:00:36.03 bitrate=63089.8kbits/s speed=1.69x
# frame= 1131 fps= 52 q=0.0 size=  285184kB time=00:00:37.03 bitrate=63085.1kbits/s speed= 1.7x
# frame= 1161 fps= 52 q=0.0 size=  292864kB time=00:00:38.03 bitrate=63080.6kbits/s speed= 1.7x
# frame= 1191 fps= 52 q=0.0 size=  300544kB time=00:00:39.03 bitrate=63076.4kbits/s speed=1.71x
# frame= 1221 fps= 52 q=0.0 size=  308224kB time=00:00:40.03 bitrate=63072.4kbits/s speed=1.71x
# frame= 1251 fps= 52 q=0.0 size=  315904kB time=00:00:41.03 bitrate=63068.5kbits/s speed=1.72x
# frame= 1281 fps= 52 q=0.0 size=  323840kB time=00:00:42.03 bitrate=63114.8kbits/s speed=1.72x
# frame= 1311 fps= 53 q=0.0 size=  331776kB time=00:00:43.03 bitrate=63158.9kbits/s speed=1.73x
# frame= 1341 fps= 53 q=0.0 size=  339200kB time=00:00:44.03 bitrate=63105.7kbits/s speed=1.73x
# frame= 1371 fps= 53 q=0.0 size=  346880kB time=00:00:45.03 bitrate=63101.5kbits/s speed=1.73x
# frame= 1401 fps= 53 q=0.0 size=  354560kB time=00:00:46.03 bitrate=63097.4kbits/s speed=1.73x
# frame= 1431 fps= 53 q=0.0 size=  362240kB time=00:00:47.03 bitrate=63093.6kbits/s speed=1.73x
# frame= 1461 fps= 53 q=0.0 size=  370432kB time=00:00:48.03 bitrate=63177.2kbits/s speed=1.73x
# frame= 1491 fps= 53 q=0.0 size=  378368kB time=00:00:49.03 bitrate=63214.6kbits/s speed=1.74x
# frame= 1520 fps= 53 q=0.0 size=  385536kB time=00:00:49.99 bitrate=63166.9kbits/s speed=1.74x
# frame= 1551 fps= 53 q=0.0 size=  393472kB time=00:00:51.03 bitrate=63161.8kbits/s speed=1.74x
# frame= 1581 fps= 53 q=0.0 size=  401152kB time=00:00:52.03 bitrate=63157.0kbits/s speed=1.74x
# frame= 1611 fps= 53 q=0.0 size=  408832kB time=00:00:53.03 bitrate=63152.5kbits/s speed=1.74x
# frame= 1641 fps= 53 q=0.0 size=  416256kB time=00:00:54.03 bitrate=63109.3kbits/s speed=1.74x
# frame= 1671 fps= 53 q=0.0 size=  423936kB time=00:00:55.03 bitrate=63105.7kbits/s speed=1.74x
# frame= 1701 fps= 53 q=0.0 size=  431616kB time=00:00:56.03 bitrate=63102.3kbits/s speed=1.74x
# frame= 1731 fps= 53 q=0.0 size=  439040kB time=00:00:57.03 bitrate=63062.3kbits/s speed=1.75x
# frame= 1761 fps= 53 q=0.0 size=  446976kB time=00:00:58.03 bitrate=63095.9kbits/s speed=1.74x
# frame= 1791 fps= 53 q=0.0 size=  454912kB time=00:00:59.03 bitrate=63128.3kbits/s speed=1.74x
# frame= 1800 fps= 52 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.72x
# frame= 1800 fps= 51 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed= 1.7x
# frame= 1800 fps= 51 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.67x
# frame= 1800 fps= 50 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.65x
# frame= 1800 fps= 49 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.63x
# frame= 1800 fps= 49 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed= 1.6x
# frame= 1800 fps= 48 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.58x
# frame= 1800 fps= 47 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.56x
# frame= 1800 fps= 47 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.54x
# frame= 1800 fps= 46 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.52x
# frame= 1800 fps= 46 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed= 1.5x
# frame= 1800 fps= 45 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.48x
# frame= 1800 fps= 44 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.47x
# frame= 1800 fps= 44 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.45x
# frame= 1800 fps= 43 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.43x
# frame= 1800 fps= 43 q=0.0 size=  457216kB time=00:00:59.33 bitrate=63127.3kbits/s speed=1.41x
# frame= 1800 fps= 42 q=-1.0 Lsize=  461839kB time=00:00:59.96 bitrate=63092.2kbits/s speed=1.41x
# video:461828kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002513%
# [libx264 @ 0000021d68fb9a00] frame I:8     Avg QP: 0.00  size:604926
# [libx264 @ 0000021d68fb9a00] frame P:1792  Avg QP: 0.00  size:261201
# [libx264 @ 0000021d68fb9a00] mb I  I16..4: 24.4% 14.4% 61.2%
# [libx264 @ 0000021d68fb9a00] mb P  I16..4:  5.3%  3.8%  1.0%  P16..4: 53.6% 12.6% 18.2%  0.0%  0.0%    skip: 5.4%
# [libx264 @ 0000021d68fb9a00] 8x8 transform intra:36.7% inter:34.1%
# [libx264 @ 0000021d68fb9a00] coded y,uvDC,uvAC intra: 83.6% 23.3% 22.1% inter: 74.0% 6.8% 6.5%
# [libx264 @ 0000021d68fb9a00] i16 v,h,dc,p: 66% 33%  1%  0%
# [libx264 @ 0000021d68fb9a00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 28% 35%  3%  3%  1%  1%  1%  1%
# [libx264 @ 0000021d68fb9a00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 38%  2%  2%  4%  2%  3%  2%  2%
# [libx264 @ 0000021d68fb9a00] i8c dc,h,v,p: 63% 14% 23%  0%
# [libx264 @ 0000021d68fb9a00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0000021d68fb9a00] ref P L0: 88.0%  8.1%  2.9%  1.0%
# [libx264 @ 0000021d68fb9a00] kb/s:63055.46
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 9.2.1 (GCC) 20200122
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libmfx --enable-amf --enable-ffnvcodec --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:/big_setup/experiment_530/videos/center-20260302T144637-145138.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.00, start: 0.000000, bitrate: 7696 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1600x1200, 7693 kb/s, 30 fps, 30 tbr, 10000k tbn, 20000k tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 00000219c29b9a00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 00000219c29b9a00] profile High 4:4:4 Predictive, level 4.0, 4:2:0, 8-bit
# [libx264 @ 00000219c29b9a00] 64 - core 159 - H.264/MPEG-4 AVC codec - Copyleft 2003-2019 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to 'D:/big_setup/experiment_530/videos/center-20260302T144637-145138_trunc_1.mp4':
#   Metadata:
#     major_brand     : isml
#     minor_version   : 512
#     compatible_brands: ismlpiff
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1600x1200, q=-1--1, 30 fps, 1000k tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    6 fps=3.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   41 fps= 16 q=0.0 size=    6144kB time=00:00:00.69 bitrate=71903.5kbits/s speed=0.277x
# frame=   68 fps= 22 q=0.0 size=   13568kB time=00:00:01.59 bitrate=69469.1kbits/s speed=0.529x
# frame=   96 fps= 27 q=0.0 size=   20480kB time=00:00:02.53 bitrate=66226.6kbits/s speed=0.717x
# frame=  125 fps= 31 q=0.0 size=   27904kB time=00:00:03.49 bitrate=65312.0kbits/s speed=0.867x
# frame=  155 fps= 34 q=0.0 size=   35584kB time=00:00:04.49 bitrate=64779.4kbits/s speed=0.992x
# frame=  183 fps= 36 q=0.0 size=   42752kB time=00:00:05.43 bitrate=64459.2kbits/s speed=1.08x
# frame=  211 fps= 38 q=0.0 size=   49920kB time=00:00:06.36 bitrate=64232.8kbits/s speed=1.15x
# frame=  241 fps= 40 q=0.0 size=   57600kB time=00:00:07.36 bitrate=64054.0kbits/s speed=1.21x
# frame=  271 fps= 41 q=0.0 size=   65536kB time=00:00:08.36 bitrate=64168.5kbits/s speed=1.27x
# frame=  304 fps= 43 q=0.0 size=   73984kB time=00:00:09.46 bitrate=64022.9kbits/s speed=1.34x
# frame=  333 fps= 44 q=0.0 size=   81408kB time=00:00:10.43 bitrate=63920.3kbits/s speed=1.38x
# frame=  361 fps= 45 q=0.0 size=   88320kB time=00:00:11.36 bitrate=63653.2kbits/s speed= 1.4x
# frame=  389 fps= 45 q=0.0 size=   95488kB time=00:00:12.29 bitrate=63597.2kbits/s speed=1.43x
# frame=  417 fps= 46 q=0.0 size=  102656kB time=00:00:13.23 bitrate=63549.1kbits/s speed=1.45x
# frame=  447 fps= 47 q=0.0 size=  110336kB time=00:00:14.23 bitrate=63504.6kbits/s speed=1.48x
# frame=  478 fps= 47 q=0.0 size=  118016kB time=00:00:15.26 bitrate=63327.3kbits/s speed=1.51x
# frame=  509 fps= 48 q=0.0 size=  125952kB time=00:00:16.29 bitrate=63301.2kbits/s speed=1.53x
# frame=  536 fps= 48 q=0.0 size=  133120kB time=00:00:17.19 bitrate=63402.9kbits/s speed=1.55x
# frame=  562 fps= 48 q=0.0 size=  139776kB time=00:00:18.06 bitrate=63379.5kbits/s speed=1.55x
# frame=  592 fps= 49 q=0.0 size=  147200kB time=00:00:19.06 bitrate=63245.2kbits/s speed=1.56x
# frame=  622 fps= 49 q=0.0 size=  154880kB time=00:00:20.06 bitrate=63228.7kbits/s speed=1.58x
# frame=  652 fps= 49 q=0.0 size=  162304kB time=00:00:21.06 bitrate=63114.3kbits/s speed=1.59x
# frame=  685 fps= 50 q=0.0 size=  170752kB time=00:00:22.16 bitrate=63104.4kbits/s speed=1.61x
# frame=  716 fps= 50 q=0.0 size=  178688kB time=00:00:23.19 bitrate=63096.0kbits/s speed=1.62x
# frame=  747 fps= 50 q=0.0 size=  186368kB time=00:00:24.23 bitrate=63001.7kbits/s speed=1.64x
# frame=  778 fps= 51 q=0.0 size=  194816kB time=00:00:25.26 bitrate=63164.2kbits/s speed=1.65x
# frame=  802 fps= 51 q=0.0 size=  200704kB time=00:00:26.06 bitrate=63076.1kbits/s speed=1.64x
# frame=  832 fps= 51 q=0.0 size=  208384kB time=00:00:27.06 bitrate=63070.2kbits/s speed=1.66x
# frame=  862 fps= 51 q=0.0 size=  216064kB time=00:00:28.06 bitrate=63064.6kbits/s speed=1.66x
# frame=  894 fps= 51 q=0.0 size=  224000kB time=00:00:29.13 bitrate=62987.2kbits/s speed=1.67x
# frame=  926 fps= 52 q=0.0 size=  232192kB time=00:00:30.19 bitrate=62984.6kbits/s speed=1.69x
# frame=  956 fps= 52 q=0.0 size=  239872kB time=00:00:31.19 bitrate=62982.4kbits/s speed= 1.7x
# frame=  987 fps= 52 q=0.0 size=  247552kB time=00:00:32.23 bitrate=62915.2kbits/s speed=1.71x
# frame= 1013 fps= 52 q=0.0 size=  254208kB time=00:00:33.09 bitrate=62915.2kbits/s speed=1.71x
# frame= 1050 fps= 53 q=0.0 size=  263936kB time=00:00:34.33 bitrate=62976.3kbits/s speed=1.72x
# frame= 1078 fps= 53 q=0.0 size=  271104kB time=00:00:35.26 bitrate=62974.7kbits/s speed=1.73x
# frame= 1111 fps= 53 q=0.0 size=  279296kB time=00:00:36.36 bitrate=62915.2kbits/s speed=1.74x
# frame= 1141 fps= 53 q=0.0 size=  286976kB time=00:00:37.36 bitrate=62915.2kbits/s speed=1.74x
# frame= 1171 fps= 53 q=0.0 size=  294656kB time=00:00:38.36 bitrate=62915.2kbits/s speed=1.75x
# frame= 1200 fps= 53 q=0.0 size=  302080kB time=00:00:39.33 bitrate=62915.2kbits/s speed=1.75x
# frame= 1230 fps= 54 q=0.0 size=  309504kB time=00:00:40.33 bitrate=62863.2kbits/s speed=1.76x
# frame= 1259 fps= 54 q=0.0 size=  316928kB time=00:00:41.29 bitrate=62864.4kbits/s speed=1.76x
# frame= 1291 fps= 54 q=0.0 size=  325376kB time=00:00:42.36 bitrate=62915.2kbits/s speed=1.77x
# frame= 1319 fps= 54 q=0.0 size=  332544kB time=00:00:43.29 bitrate=62915.2kbits/s speed=1.77x
# frame= 1351 fps= 54 q=0.0 size=  340480kB time=00:00:44.36 bitrate=62867.9kbits/s speed=1.77x
# frame= 1379 fps= 54 q=0.0 size=  347648kB time=00:00:45.29 bitrate=62868.9kbits/s speed=1.78x
# frame= 1410 fps= 54 q=0.0 size=  355584kB time=00:00:46.33 bitrate=62869.9kbits/s speed=1.78x
# frame= 1438 fps= 54 q=0.0 size=  362752kB time=00:00:47.26 bitrate=62870.8kbits/s speed=1.78x
# frame= 1471 fps= 54 q=0.0 size=  370944kB time=00:00:48.36 bitrate=62828.5kbits/s speed=1.79x
# frame= 1500 fps= 54 q=0.0 size=  378368kB time=00:00:49.33 bitrate=62830.2kbits/s speed=1.79x
# frame= 1532 fps= 55 q=0.0 size=  386816kB time=00:00:50.39 bitrate=62873.6kbits/s speed= 1.8x
# frame= 1562 fps= 55 q=0.0 size=  394496kB time=00:00:51.39 bitrate=62874.4kbits/s speed= 1.8x
# frame= 1591 fps= 55 q=0.0 size=  401664kB time=00:00:52.36 bitrate=62835.1kbits/s speed= 1.8x
# frame= 1622 fps= 55 q=0.0 size=  409600kB time=00:00:53.39 bitrate=62836.6kbits/s speed=1.81x
# frame= 1654 fps= 55 q=0.0 size=  417792kB time=00:00:54.46 bitrate=62838.2kbits/s speed=1.81x
# frame= 1685 fps= 55 q=0.0 size=  425472kB time=00:00:55.49 bitrate=62801.8kbits/s speed=1.81x
# frame= 1716 fps= 55 q=0.0 size=  433408kB time=00:00:56.53 bitrate=62803.9kbits/s speed=1.82x
# frame= 1748 fps= 55 q=0.0 size=  441344kB time=00:00:57.59 bitrate=62769.6kbits/s speed=1.82x
# frame= 1780 fps= 55 q=0.0 size=  449792kB time=00:00:58.66 bitrate=62808.0kbits/s speed=1.82x
# frame= 1812 fps= 55 q=0.0 size=  457984kB time=00:00:59.73 bitrate=62809.9kbits/s speed=1.83x
# frame= 1841 fps= 55 q=0.0 size=  465152kB time=00:01:00.69 bitrate=62777.0kbits/s speed=1.83x
# frame= 1872 fps= 55 q=0.0 size=  473088kB time=00:01:01.73 bitrate=62779.3kbits/s speed=1.83x
# frame= 1903 fps= 56 q=0.0 size=  481024kB time=00:01:02.76 bitrate=62781.5kbits/s speed=1.83x
# frame= 1933 fps= 56 q=0.0 size=  488448kB time=00:01:03.76 bitrate=62750.8kbits/s speed=1.83x
# frame= 1963 fps= 56 q=0.0 size=  496128kB time=00:01:04.76 bitrate=62753.3kbits/s speed=1.84x
# frame= 1991 fps= 56 q=0.0 size=  503296kB time=00:01:05.69 bitrate=62755.6kbits/s speed=1.84x
# frame= 2021 fps= 56 q=0.0 size=  511232kB time=00:01:06.69 bitrate=62789.4kbits/s speed=1.84x
# frame= 2050 fps= 56 q=0.0 size=  518656kB time=00:01:07.66 bitrate=62791.2kbits/s speed=1.84x
# frame= 2080 fps= 56 q=0.0 size=  526336kB time=00:01:08.66 bitrate=62793.0kbits/s speed=1.84x
# frame= 2110 fps= 56 q=0.0 size=  533760kB time=00:01:09.66 bitrate=62764.7kbits/s speed=1.84x
# frame= 2137 fps= 56 q=0.0 size=  540672kB time=00:01:10.56 bitrate=62766.6kbits/s speed=1.84x
# frame= 2159 fps= 55 q=0.0 size=  546304kB time=00:01:11.29 bitrate=62768.1kbits/s speed=1.83x
# frame= 2182 fps= 55 q=0.0 size=  552192kB time=00:01:12.06 bitrate=62769.7kbits/s speed=1.83x
# frame= 2212 fps= 55 q=0.0 size=  559872kB time=00:01:13.06 bitrate=62771.7kbits/s speed=1.82x
# frame= 2242 fps= 55 q=0.0 size=  567296kB time=00:01:14.06 bitrate=62745.3kbits/s speed=1.82x
# frame= 2273 fps= 55 q=0.0 size=  575744kB time=00:01:15.09 bitrate=62803.5kbits/s speed=1.82x
# frame= 2302 fps= 55 q=0.0 size=  582912kB time=00:01:16.06 bitrate=62777.3kbits/s speed=1.82x
# frame= 2332 fps= 55 q=0.0 size=  590592kB time=00:01:17.06 bitrate=62779.1kbits/s speed=1.82x
# frame= 2362 fps= 55 q=0.0 size=  598272kB time=00:01:18.06 bitrate=62780.9kbits/s speed=1.82x
# frame= 2392 fps= 55 q=0.0 size=  605696kB time=00:01:19.06 bitrate=62756.0kbits/s speed=1.82x
# frame= 2424 fps= 55 q=0.0 size=  613888kB time=00:01:20.13 bitrate=62758.2kbits/s speed=1.82x
# frame= 2452 fps= 55 q=0.0 size=  621056kB time=00:01:21.06 bitrate=62760.0kbits/s speed=1.82x
# frame= 2482 fps= 55 q=0.0 size=  628480kB time=00:01:22.06 bitrate=62736.3kbits/s speed=1.82x
# frame= 2512 fps= 55 q=0.0 size=  636160kB time=00:01:23.06 bitrate=62738.5kbits/s speed=1.82x
# frame= 2548 fps= 55 q=0.0 size=  645632kB time=00:01:24.26 bitrate=62765.9kbits/s speed=1.83x
# frame= 2577 fps= 55 q=0.0 size=  653056kB time=00:01:25.23 bitrate=62767.6kbits/s speed=1.83x
# frame= 2610 fps= 55 q=0.0 size=  661504kB time=00:01:26.33 bitrate=62769.4kbits/s speed=1.84x
# frame= 2642 fps= 56 q=0.0 size=  669440kB time=00:01:27.39 bitrate=62747.2kbits/s speed=1.84x
# frame= 2670 fps= 56 q=0.0 size=  676608kB time=00:01:28.33 bitrate=62749.0kbits/s speed=1.84x
# frame= 2701 fps= 56 q=0.0 size=  684544kB time=00:01:29.36 bitrate=62750.9kbits/s speed=1.84x
# frame= 2732 fps= 56 q=0.0 size=  692480kB time=00:01:30.39 bitrate=62752.8kbits/s speed=1.84x
# frame= 2763 fps= 56 q=0.0 size=  700416kB time=00:01:31.43 bitrate=62754.6kbits/s speed=1.84x
# frame= 2795 fps= 56 q=0.0 size=  709120kB time=00:01:32.49 bitrate=62801.8kbits/s speed=1.85x
# frame= 2826 fps= 56 q=0.0 size=  717056kB time=00:01:33.53 bitrate=62803.1kbits/s speed=1.85x
# frame= 2856 fps= 56 q=0.0 size=  724992kB time=00:01:34.53 bitrate=62826.5kbits/s speed=1.85x
# frame= 2887 fps= 56 q=0.0 size=  732928kB time=00:01:35.56 bitrate=62827.4kbits/s speed=1.85x
# frame= 2920 fps= 56 q=0.0 size=  741376kB time=00:01:36.66 bitrate=62828.4kbits/s speed=1.85x
# frame= 2950 fps= 56 q=0.0 size=  749056kB time=00:01:37.66 bitrate=62829.3kbits/s speed=1.85x
# frame= 2981 fps= 56 q=0.0 size=  756992kB time=00:01:38.69 bitrate=62830.2kbits/s speed=1.85x
# frame= 3012 fps= 56 q=0.0 size=  765184kB time=00:01:39.73 bitrate=62852.1kbits/s speed=1.85x
# frame= 3043 fps= 56 q=0.0 size=  773632kB time=00:01:40.76 bitrate=62894.4kbits/s speed=1.86x
# frame= 3070 fps= 56 q=0.0 size=  780544kB time=00:01:41.66 bitrate=62894.6kbits/s speed=1.85x
# frame= 3100 fps= 56 q=0.0 size=  788224kB time=00:01:42.66 bitrate=62894.8kbits/s speed=1.85x
# frame= 3128 fps= 56 q=0.0 size=  795392kB time=00:01:43.59 bitrate=62894.9kbits/s speed=1.85x
# frame= 3160 fps= 56 q=0.0 size=  803584kB time=00:01:44.66 bitrate=62895.2kbits/s speed=1.86x
# frame= 3190 fps= 56 q=0.0 size=  811520kB time=00:01:45.66 bitrate=62915.2kbits/s speed=1.86x
# frame= 3221 fps= 56 q=0.0 size=  819200kB time=00:01:46.69 bitrate=62895.5kbits/s speed=1.86x
# frame= 3250 fps= 56 q=0.0 size=  826624kB time=00:01:47.66 bitrate=62895.7kbits/s speed=1.86x
# frame= 3280 fps= 56 q=0.0 size=  834816kB time=00:01:48.66 bitrate=62934.5kbits/s speed=1.86x
# frame= 3311 fps= 56 q=0.0 size=  842752kB time=00:01:49.69 bitrate=62934.3kbits/s speed=1.86x
# frame= 3343 fps= 56 q=0.0 size=  850944kB time=00:01:50.76 bitrate=62934.1kbits/s speed=1.86x
# frame= 3371 fps= 56 q=0.0 size=  858112kB time=00:01:51.69 bitrate=62934.0kbits/s speed=1.86x
# frame= 3401 fps= 56 q=0.0 size=  865792kB time=00:01:52.69 bitrate=62933.8kbits/s speed=1.86x
# frame= 3430 fps= 56 q=0.0 size=  873472kB time=00:01:53.66 bitrate=62952.1kbits/s speed=1.86x
# frame= 3461 fps= 56 q=0.0 size=  881408kB time=00:01:54.69 bitrate=62951.8kbits/s speed=1.86x
# frame= 3489 fps= 56 q=0.0 size=  889088kB time=00:01:55.63 bitrate=62987.7kbits/s speed=1.86x
# frame= 3518 fps= 56 q=0.0 size=  897024kB time=00:01:56.59 bitrate=63023.1kbits/s speed=1.86x
# frame= 3548 fps= 56 q=0.0 size=  904960kB time=00:01:57.59 bitrate=63040.0kbits/s speed=1.87x
# frame= 3574 fps= 56 q=0.0 size=  912128kB time=00:01:58.46 bitrate=63074.5kbits/s speed=1.86x
# frame= 3606 fps= 56 q=0.0 size=  920064kB time=00:01:59.53 bitrate=63055.5kbits/s speed=1.87x
# frame= 3637 fps= 56 q=0.0 size=  928000kB time=00:02:00.56 bitrate=63054.3kbits/s speed=1.87x
# frame= 3667 fps= 56 q=0.0 size=  935680kB time=00:02:01.56 bitrate=63053.2kbits/s speed=1.87x
# frame= 3696 fps= 56 q=0.0 size=  943104kB time=00:02:02.53 bitrate=63052.1kbits/s speed=1.87x
# frame= 3727 fps= 56 q=0.0 size=  951040kB time=00:02:03.56 bitrate=63051.0kbits/s speed=1.87x
# frame= 3759 fps= 56 q=0.0 size=  958976kB time=00:02:04.63 bitrate=63033.0kbits/s speed=1.87x
# frame= 3790 fps= 56 q=0.0 size=  967168kB time=00:02:05.66 bitrate=63048.7kbits/s speed=1.87x
# frame= 3820 fps= 56 q=0.0 size=  974848kB time=00:02:06.66 bitrate=63047.6kbits/s speed=1.87x
# frame= 3850 fps= 56 q=0.0 size=  982528kB time=00:02:07.66 bitrate=63046.6kbits/s speed=1.87x
# frame= 3880 fps= 56 q=0.0 size=  990208kB time=00:02:08.66 bitrate=63045.6kbits/s speed=1.87x
# frame= 3911 fps= 56 q=0.0 size=  998144kB time=00:02:09.69 bitrate=63044.5kbits/s speed=1.87x
# frame= 3940 fps= 56 q=0.0 size= 1006080kB time=00:02:10.66 bitrate=63075.7kbits/s speed=1.87x
# frame= 3971 fps= 57 q=0.0 size= 1014016kB time=00:02:11.69 bitrate=63074.4kbits/s speed=1.87x
# frame= 4000 fps= 56 q=0.0 size= 1021952kB time=00:02:12.66 bitrate=63104.9kbits/s speed=1.87x
# frame= 4030 fps= 56 q=0.0 size= 1030656kB time=00:02:13.66 bitrate=63166.2kbits/s speed=1.87x
# frame= 4060 fps= 56 q=0.0 size= 1038848kB time=00:02:14.66 bitrate=63195.5kbits/s speed=1.87x
# frame= 4091 fps= 57 q=0.0 size= 1046784kB time=00:02:15.69 bitrate=63193.4kbits/s speed=1.87x
# frame= 4120 fps= 57 q=0.0 size= 1054464kB time=00:02:16.66 bitrate=63206.7kbits/s speed=1.87x
# frame= 4150 fps= 57 q=0.0 size= 1062144kB time=00:02:17.66 bitrate=63204.6kbits/s speed=1.88x
# frame= 4180 fps= 57 q=0.0 size= 1069824kB time=00:02:18.66 bitrate=63202.5kbits/s speed=1.88x
# frame= 4212 fps= 57 q=0.0 size= 1078016kB time=00:02:19.73 bitrate=63200.4kbits/s speed=1.88x
# frame= 4241 fps= 57 q=0.0 size= 1085696kB time=00:02:20.69 bitrate=63213.3kbits/s speed=1.88x
# frame= 4270 fps= 57 q=0.0 size= 1093632kB time=00:02:21.66 bitrate=63240.9kbits/s speed=1.88x
# frame= 4300 fps= 57 q=0.0 size= 1101312kB time=00:02:22.66 bitrate=63238.6kbits/s speed=1.88x
# frame= 4332 fps= 57 q=0.0 size= 1109504kB time=00:02:23.73 bitrate=63236.2kbits/s speed=1.88x
# frame= 4363 fps= 57 q=0.0 size= 1117440kB time=00:02:24.76 bitrate=63233.9kbits/s speed=1.88x
# frame= 4392 fps= 57 q=0.0 size= 1124864kB time=00:02:25.73 bitrate=63231.8kbits/s speed=1.88x
# frame= 4423 fps= 57 q=0.0 size= 1132800kB time=00:02:26.76 bitrate=63229.6kbits/s speed=1.88x
# frame= 4455 fps= 57 q=0.0 size= 1140992kB time=00:02:27.83 bitrate=63227.3kbits/s speed=1.88x
# frame= 4485 fps= 57 q=0.0 size= 1148672kB time=00:02:28.83 bitrate=63225.2kbits/s speed=1.88x
# frame= 4514 fps= 57 q=0.0 size= 1156096kB time=00:02:29.79 bitrate=63223.2kbits/s speed=1.88x
# frame= 4546 fps= 57 q=0.0 size= 1164800kB time=00:02:30.86 bitrate=63248.8kbits/s speed=1.88x
# frame= 4573 fps= 57 q=0.0 size= 1171968kB time=00:02:31.76 bitrate=63260.7kbits/s speed=1.88x
# frame= 4604 fps= 57 q=0.0 size= 1180160kB time=00:02:32.79 bitrate=63272.0kbits/s speed=1.88x
# frame= 4634 fps= 57 q=0.0 size= 1187840kB time=00:02:33.79 bitrate=63269.7kbits/s speed=1.88x
# frame= 4665 fps= 57 q=0.0 size= 1196032kB time=00:02:34.83 bitrate=63280.9kbits/s speed=1.89x
# frame= 4694 fps= 57 q=0.0 size= 1203456kB time=00:02:35.79 bitrate=63278.6kbits/s speed=1.89x
# frame= 4725 fps= 57 q=0.0 size= 1211648kB time=00:02:36.83 bitrate=63289.6kbits/s speed=1.89x
# frame= 4750 fps= 57 q=0.0 size= 1218560kB time=00:02:37.66 bitrate=63314.2kbits/s speed=1.88x
# frame= 4780 fps= 57 q=0.0 size= 1226752kB time=00:02:38.66 bitrate=63338.2kbits/s speed=1.88x
# frame= 4811 fps= 57 q=0.0 size= 1234944kB time=00:02:39.69 bitrate=63348.5kbits/s speed=1.89x
# frame= 4841 fps= 57 q=0.0 size= 1242880kB time=00:02:40.69 bitrate=63358.9kbits/s speed=1.89x
# frame= 4870 fps= 57 q=0.0 size= 1250560kB time=00:02:41.66 bitrate=63369.2kbits/s speed=1.89x
# frame= 4900 fps= 57 q=0.0 size= 1258496kB time=00:02:42.66 bitrate=63379.3kbits/s speed=1.89x
# frame= 4930 fps= 57 q=0.0 size= 1266432kB time=00:02:43.66 bitrate=63389.3kbits/s speed=1.89x
# frame= 4962 fps= 57 q=0.0 size= 1274880kB time=00:02:44.73 bitrate=63399.0kbits/s speed=1.89x
# frame= 4992 fps= 57 q=0.0 size= 1282816kB time=00:02:45.73 bitrate=63408.7kbits/s speed=1.89x
# frame= 5020 fps= 57 q=0.0 size= 1290752kB time=00:02:46.66 bitrate=63443.7kbits/s speed=1.89x
# frame= 5050 fps= 57 q=0.0 size= 1298688kB time=00:02:47.66 bitrate=63453.0kbits/s speed=1.89x
# frame= 5081 fps= 57 q=0.0 size= 1306624kB time=00:02:48.69 bitrate=63449.7kbits/s speed=1.89x
# frame= 5110 fps= 57 q=0.0 size= 1314304kB time=00:02:49.66 bitrate=63459.1kbits/s speed=1.89x
# frame= 5140 fps= 57 q=0.0 size= 1321984kB time=00:02:50.66 bitrate=63455.9kbits/s speed=1.89x
# frame= 5170 fps= 57 q=0.0 size= 1329664kB time=00:02:51.66 bitrate=63452.7kbits/s speed=1.89x
# frame= 5200 fps= 57 q=0.0 size= 1337600kB time=00:02:52.66 bitrate=63461.8kbits/s speed=1.89x
# frame= 5230 fps= 57 q=0.0 size= 1345280kB time=00:02:53.66 bitrate=63458.6kbits/s speed=1.89x
# frame= 5260 fps= 57 q=0.0 size= 1352960kB time=00:02:54.66 bitrate=63455.5kbits/s speed=1.89x
# frame= 5292 fps= 57 q=0.0 size= 1361920kB time=00:02:55.73 bitrate=63488.0kbits/s speed=1.89x
# frame= 5320 fps= 57 q=0.0 size= 1369088kB time=00:02:56.66 bitrate=63485.0kbits/s speed=1.89x
# frame= 5350 fps= 57 q=0.0 size= 1377024kB time=00:02:57.66 bitrate=63493.6kbits/s speed=1.89x
# frame= 5380 fps= 57 q=0.0 size= 1384960kB time=00:02:58.66 bitrate=63502.1kbits/s speed=1.89x
# frame= 5410 fps= 57 q=0.0 size= 1392896kB time=00:02:59.66 bitrate=63510.5kbits/s speed=1.89x
# frame= 5440 fps= 57 q=0.0 size= 1400832kB time=00:03:00.66 bitrate=63518.8kbits/s speed=1.89x
# frame= 5465 fps= 57 q=0.0 size= 1407488kB time=00:03:01.49 bitrate=63527.6kbits/s speed=1.89x
# frame= 5493 fps= 57 q=0.0 size= 1414912kB time=00:03:02.43 bitrate=63536.0kbits/s speed=1.88x
# frame= 5519 fps= 57 q=0.0 size= 1421824kB time=00:03:03.29 bitrate=63544.5kbits/s speed=1.88x
# frame= 5549 fps= 57 q=0.0 size= 1430016kB time=00:03:04.29 bitrate=63563.8kbits/s speed=1.88x
# frame= 5577 fps= 57 q=0.0 size= 1437696kB time=00:03:05.23 bitrate=63583.2kbits/s speed=1.88x
# frame= 5609 fps= 57 q=0.0 size= 1445888kB time=00:03:06.29 bitrate=63579.4kbits/s speed=1.89x
# frame= 5637 fps= 57 q=0.0 size= 1453312kB time=00:03:07.23 bitrate=63587.2kbits/s speed=1.89x
# frame= 5666 fps= 57 q=0.0 size= 1460736kB time=00:03:08.19 bitrate=63583.8kbits/s speed=1.89x
# frame= 5696 fps= 57 q=0.0 size= 1468416kB time=00:03:09.19 bitrate=63580.3kbits/s speed=1.89x
# frame= 5729 fps= 57 q=0.0 size= 1477120kB time=00:03:10.29 bitrate=63587.4kbits/s speed=1.89x
# frame= 5755 fps= 57 q=0.0 size= 1483776kB time=00:03:11.16 bitrate=63584.4kbits/s speed=1.89x
# frame= 5784 fps= 57 q=0.0 size= 1491712kB time=00:03:12.13 bitrate=63602.8kbits/s speed=1.89x
# frame= 5812 fps= 57 q=0.0 size= 1498880kB time=00:03:13.06 bitrate=63599.5kbits/s speed=1.89x
# frame= 5842 fps= 57 q=0.0 size= 1506560kB time=00:03:14.06 bitrate=63596.0kbits/s speed=1.89x
# frame= 5872 fps= 57 q=0.0 size= 1514496kB time=00:03:15.06 bitrate=63603.3kbits/s speed=1.89x
# frame= 5902 fps= 57 q=0.0 size= 1522432kB time=00:03:16.06 bitrate=63610.4kbits/s speed=1.89x
# frame= 5933 fps= 57 q=0.0 size= 1530368kB time=00:03:17.09 bitrate=63606.8kbits/s speed=1.89x
# frame= 5963 fps= 57 q=0.0 size= 1538304kB time=00:03:18.09 bitrate=63613.9kbits/s speed=1.89x
# frame= 5994 fps= 57 q=0.0 size= 1546240kB time=00:03:19.13 bitrate=63610.3kbits/s speed=1.89x
# frame= 6029 fps= 57 q=0.0 size= 1555712kB time=00:03:20.29 bitrate=63627.2kbits/s speed=1.89x
# frame= 6053 fps= 57 q=0.0 size= 1562112kB time=00:03:21.09 bitrate=63634.8kbits/s speed=1.89x
# frame= 6082 fps= 57 q=0.0 size= 1569792kB time=00:03:22.06 bitrate=63641.7kbits/s speed=1.89x
# frame= 6112 fps= 57 q=0.0 size= 1577472kB time=00:03:23.06 bitrate=63638.1kbits/s speed=1.89x
# frame= 6142 fps= 57 q=0.0 size= 1585408kB time=00:03:24.06 bitrate=63644.9kbits/s speed=1.89x
# frame= 6172 fps= 57 q=0.0 size= 1593344kB time=00:03:25.06 bitrate=63651.5kbits/s speed=1.89x
# frame= 6202 fps= 57 q=0.0 size= 1601280kB time=00:03:26.06 bitrate=63658.1kbits/s speed=1.89x
# frame= 6232 fps= 57 q=0.0 size= 1609216kB time=00:03:27.06 bitrate=63664.7kbits/s speed=1.89x
# frame= 6262 fps= 57 q=0.0 size= 1617408kB time=00:03:28.06 bitrate=63681.2kbits/s speed=1.89x
# frame= 6296 fps= 57 q=0.0 size= 1626624kB time=00:03:29.19 bitrate=63697.1kbits/s speed=1.89x
# frame= 6324 fps= 57 q=0.0 size= 1633792kB time=00:03:30.13 bitrate=63693.6kbits/s speed=1.89x
# frame= 6352 fps= 57 q=0.0 size= 1641216kB time=00:03:31.06 bitrate=63700.1kbits/s speed=1.89x
# frame= 6382 fps= 57 q=0.0 size= 1648896kB time=00:03:32.06 bitrate=63696.4kbits/s speed=1.89x
# frame= 6412 fps= 57 q=0.0 size= 1656576kB time=00:03:33.06 bitrate=63692.8kbits/s speed=1.89x
# frame= 6442 fps= 57 q=0.0 size= 1664256kB time=00:03:34.06 bitrate=63689.1kbits/s speed=1.89x
# frame= 6472 fps= 57 q=0.0 size= 1672192kB time=00:03:35.06 bitrate=63695.3kbits/s speed=1.89x
# frame= 6502 fps= 57 q=0.0 size= 1680128kB time=00:03:36.06 bitrate=63701.4kbits/s speed=1.89x
# frame= 6532 fps= 57 q=0.0 size= 1688320kB time=00:03:37.06 bitrate=63717.1kbits/s speed=1.89x
# frame= 6562 fps= 57 q=0.0 size= 1696000kB time=00:03:38.06 bitrate=63713.4kbits/s speed=1.89x
# frame= 6592 fps= 57 q=0.0 size= 1703680kB time=00:03:39.06 bitrate=63709.8kbits/s speed=1.89x
# frame= 6622 fps= 57 q=0.0 size= 1711360kB time=00:03:40.06 bitrate=63706.2kbits/s speed=1.89x
# frame= 6652 fps= 57 q=0.0 size= 1719040kB time=00:03:41.06 bitrate=63702.6kbits/s speed=1.89x
# frame= 6683 fps= 57 q=0.0 size= 1726976kB time=00:03:42.09 bitrate=63698.9kbits/s speed=1.89x
# frame= 6714 fps= 57 q=0.0 size= 1734912kB time=00:03:43.13 bitrate=63695.3kbits/s speed=1.89x
# frame= 6746 fps= 57 q=0.0 size= 1743104kB time=00:03:44.19 bitrate=63691.6kbits/s speed=1.89x
# frame= 6779 fps= 57 q=0.0 size= 1752064kB time=00:03:45.29 bitrate=63706.4kbits/s speed=1.89x
# frame= 6810 fps= 57 q=0.0 size= 1759744kB time=00:03:46.33 bitrate=63693.5kbits/s speed=1.89x
# frame= 6839 fps= 57 q=0.0 size= 1767168kB time=00:03:47.29 bitrate=63690.2kbits/s speed=1.89x
# frame= 6870 fps= 57 q=0.0 size= 1775104kB time=00:03:48.33 bitrate=63686.7kbits/s speed=1.89x
# frame= 6900 fps= 57 q=0.0 size= 1782784kB time=00:03:49.33 bitrate=63683.3kbits/s speed=1.89x
# frame= 6930 fps= 57 q=0.0 size= 1790464kB time=00:03:50.33 bitrate=63680.0kbits/s speed=1.89x
# frame= 6956 fps= 57 q=0.0 size= 1797376kB time=00:03:51.19 bitrate=63686.2kbits/s speed=1.89x
# frame= 6984 fps= 57 q=0.0 size= 1804544kB time=00:03:52.13 bitrate=63683.1kbits/s speed=1.89x
# frame= 7012 fps= 57 q=0.0 size= 1811712kB time=00:03:53.06 bitrate=63680.0kbits/s speed=1.89x
# frame= 7048 fps= 57 q=0.0 size= 1821440kB time=00:03:54.26 bitrate=63694.0kbits/s speed=1.89x
# frame= 7077 fps= 57 q=0.0 size= 1828864kB time=00:03:55.23 bitrate=63690.8kbits/s speed=1.89x
# frame= 7108 fps= 57 q=0.0 size= 1836800kB time=00:03:56.26 bitrate=63687.4kbits/s speed=1.89x
# frame= 7138 fps= 57 q=0.0 size= 1844480kB time=00:03:57.26 bitrate=63684.2kbits/s speed= 1.9x
# frame= 7168 fps= 57 q=0.0 size= 1852160kB time=00:03:58.26 bitrate=63680.9kbits/s speed= 1.9x
# frame= 7197 fps= 57 q=0.0 size= 1859584kB time=00:03:59.23 bitrate=63677.9kbits/s speed= 1.9x
# frame= 7226 fps= 57 q=0.0 size= 1867008kB time=00:04:00.19 bitrate=63674.8kbits/s speed= 1.9x
# frame= 7231 fps= 57 q=-1.0 Lsize= 1873007kB time=00:04:00.99 bitrate=63667.3kbits/s speed= 1.9x
# video:1872962kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002432%
# [libx264 @ 00000219c29b9a00] frame I:29    Avg QP: 0.00  size:640688
# [libx264 @ 00000219c29b9a00] frame P:7202  Avg QP: 0.00  size:263723
# [libx264 @ 00000219c29b9a00] mb I  I16..4: 24.8% 15.5% 59.8%
# [libx264 @ 00000219c29b9a00] mb P  I16..4:  5.5%  3.9%  1.1%  P16..4: 53.3% 12.7% 18.2%  0.0%  0.0%    skip: 5.2%
# [libx264 @ 00000219c29b9a00] 8x8 transform intra:36.5% inter:34.0%
# [libx264 @ 00000219c29b9a00] coded y,uvDC,uvAC intra: 83.9% 24.2% 23.0% inter: 74.3% 6.9% 6.7%
# [libx264 @ 00000219c29b9a00] i16 v,h,dc,p: 65% 34%  1%  0%
# [libx264 @ 00000219c29b9a00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 28% 34%  3%  3%  1%  2%  1%  1%
# [libx264 @ 00000219c29b9a00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 45% 38%  2%  2%  4%  2%  3%  2%  2%
# [libx264 @ 00000219c29b9a00] i8c dc,h,v,p: 61% 15% 24%  0%
# [libx264 @ 00000219c29b9a00] Weighted P-Frames: Y:0.1% UV:0.0%
# [libx264 @ 00000219c29b9a00] ref P L0: 87.9%  8.2%  3.0%  1.0%  0.0%
# [libx264 @ 00000219c29b9a00] kb/s:63656.97
# ^C

# %%
# # Reading the timestamps data for the camera clock channel 
# cam_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")
# for cam in camera_names:
#     no_videos = len(video_by_camera[cam])
#     filename_txt = path_concat + "video_{}.txt".format(cam)
#     f = open(filename_txt, 'w')
#     for index, vid_name in enumerate(video_by_camera[cam]):
#         if index != no_videos -1 : 
#             f.write("file \'{}\'\n".format(vid_name))
#         else: # truncating the last few seconds of the last video clip based on the timestamps generated
#             cam_stop_rec_video_name = cam_clk_data[f"{cam}_file_name"].iloc[-1]
#             cam_stop_rec_frame = int(cam_clk_data[f"{cam}_frame_idx"].iloc[-1])
#             print(cam_stop_rec_frame)
#             print(cam_stop_rec_video_name)
#             ffmpeg_extract_subclip(cam_stop_rec_video_name, 0.0, (cam_stop_rec_frame+1)/camera_fps, targetname=cam_stop_rec_video_name.split("\\")[0]+"/"+cam_stop_rec_video_name.split("\\")[1].split(".")[0]+"_trunc.mp4")
#             f.write("file \'{}\'\n".format(cam_stop_rec_video_name.split("\\")[0]+"/"+cam_stop_rec_video_name.split("\\")[1].split(".")[0]+"_trunc.mp4"))
 
#     f.close()

# %%
# Used for testing
# cam_stop_rec_video_name.split("\\")[0]+"/"+cam_stop_rec_video_name.split("\\")[1].split(".")[0]+"_trunc.mp4"

# %%
# for item in tqdm.tqdm(video_by_camera.items()):
#     fps = 30
#     resolution = (1600,1200) 
    
#     filename_txt = path_concat + "video_{}.txt".format(item[0])
#     f = open(filename_txt, 'w')

#     for idx, vid in enumerate(item[1]):
#             # if idx != (len(item[1])-1):
#             f.write("file \'{}\'\n".format(vid))
#     f.close()

# %% [markdown]
# ### For NIDAQ

# %%
# Reading the timestamps data for the camera clock channel 
audio_clk_data = pd.read_csv(f"D:/big_setup/experiment_{experiment_no}/camera_timestamps.csv")
audio_start_rec_idx = int(cam_clk_data["clk_ch_file_name"][0].split("\\")[1].split("_")[2])
audio_stop_rec_idx = int(cam_clk_data["clk_ch_file_name"].iloc[-1].split("\\")[1].split("_")[2])
start_sample_index =  int(cam_clk_data["clk_ch_sample_idx"][0])
end_sample_index =  int(cam_clk_data["clk_ch_sample_idx"].iloc[-1])

# %%
# Concatenating the microphone channels
for i in range(no_channels):
    file_break_idx = 1
    file_concat_index = 0 # index for the text files used to concatenate data
    flag = 0 # to indicate camera start record index has reached
    str_1 = "%02d"%(i)
    str_2 = "%03d"%(file_concat_index)
    filename_txt = path_concat + f"channel_{str_1}_file_{str_2}.txt"
    f = open(filename_txt, 'w')
    for idx,j in tqdm.tqdm(enumerate(nidaq_files[i::no_channels])):
            
            try:
                break_channel_idx = int(audio_clk_data.iloc[timestamp_idx[file_break_idx]][f'clk_ch_file_name'].split('_')[-2])
            except:
                 pass

            if idx == audio_start_rec_idx:            
                # Loading the file
                sampling_rate,ch = wavfile.read(j)
                ch = ch[start_sample_index:]
                target_file = j.split(".")[0]+"_trunc_0.wav"
                wavfile.write(target_file,sampling_rate,ch)
                flag = 1
                f.write("file \'{}\'\n".format(target_file))

            elif idx == break_channel_idx and idx!= audio_stop_rec_idx:

                break_sample_idx = audio_clk_data.iloc[timestamp_idx[file_break_idx]][f'clk_ch_sample_idx']
    
                # Loading the file
                sampling_rate,ch = wavfile.read(j)
                ch = ch[:break_sample_idx]
                target_file = j.split(".")[0]+"_trunc_0.wav"
                wavfile.write(target_file,sampling_rate,ch)

                f.write("file \'{}\'\n".format(target_file))
                f.close()

                
                target_file = j.split(".")[0]+"_trunc_1.wav"
                # Loading the file
                sampling_rate,ch = wavfile.read(j)
                ch = ch[break_sample_idx:]
                wavfile.write(target_file,sampling_rate,ch)

                file_concat_index+=1
                file_break_idx+=1
                str_1 = "%02d"%(i)
                str_2 = "%03d"%(file_concat_index)
                filename_txt = path_concat + f"channel_{str_1}_file_{str_2}.txt"
                f = open(filename_txt, 'w')
                f.write("file \'{}\'\n".format(target_file))
     
            elif idx != break_channel_idx and idx == audio_stop_rec_idx:
                    
            
                target_file = j.split(".")[0]+"_trunc_0.wav"

                # Loading the file
                sampling_rate,ch = wavfile.read(j)
                ch = ch[:end_sample_index]
                wavfile.write(target_file,sampling_rate,ch)
                f.write("file \'{}\'\n".format(target_file))
                f.close()
                break

            elif idx == break_channel_idx and idx == audio_stop_rec_idx:

                break_sample_idx = audio_clk_data.iloc[timestamp_idx[file_break_idx]][f'clk_ch_sample_idx']


                target_file = j.split(".")[0]+"_trunc_0.wav"
                # Loading the file
                sampling_rate,ch = wavfile.read(j)
                ch = ch[:break_sample_idx]
                wavfile.write(target_file,sampling_rate,ch)
                f.write("file \'{}\'\n".format(target_file))
                f.close()

            
                target_file = j.split(".")[0]+"_trunc_1.wav"
                # Loading the file
                sampling_rate,ch = wavfile.read(j)
                ch = ch[break_sample_idx:end_sample_index]
                wavfile.write(target_file,sampling_rate,ch)

                file_concat_index+=1
                str_1 = "%02d"%(i)
                str_2 = "%03d"%(file_concat_index)
                filename_txt = path_concat + f"channel_{str_1}_file_{str_2}.txt"
                f = open(filename_txt, 'w')
                f.write("file \'{}\'\n".format(target_file))
                f.close()
                break

            elif flag == 1:
                f.write("file \'{}\'\n".format(j))
# Out:
# 23it [00:58,  2.55s/it]
# 23it [01:15,  3.27s/it]
# 23it [01:02,  2.71s/it]
# 23it [01:08,  2.97s/it]
# 23it [00:56,  2.45s/it]
# 23it [00:56,  2.47s/it]
# 23it [01:12,  3.13s/it]
# 23it [00:59,  2.59s/it]
# 23it [01:12,  3.15s/it]
# 23it [01:00,  2.63s/it]
# 23it [01:03,  2.75s/it]
# 23it [01:09,  3.03s/it]
# 23it [01:08,  2.99s/it]
# 23it [01:00,  2.63s/it]

# %%
# # Concatenating the microphone channels
# flag = 0 # to indicate camera start record index has reached
# for i in range(no_channels):
#     concat_mic_channel = np.array([])
#     sampling_rate = 192000
#     filename_wav = path_concat + "channel_{}.txt".format(i)
#     f = open(filename_wav, 'w')
    
#     for idx,j in tqdm.tqdm(enumerate(nidaq_files[i::no_channels])):
#         if idx == cam_start_rec_idx:
#             # Loading the file
#             sampling_rate,ch = wavfile.read(j)
#             ch = ch[start_sample_index:]
#             wavfile.write(j.split(".")[0]+"_trunc.wav",sampling_rate,ch)
#             j = j.split(".")[0]+"_trunc.wav"
#             # file_lengths+=(300-)
#             flag = 1 
#         elif idx == cam_stop_rec_idx:
#             # Loading the file
#             sampling_rate,ch = wavfile.read(j)
#             ch = ch[:end_sample_index]
#             wavfile.write(j.split(".")[0]+"_trunc.wav",sampling_rate,ch)
#             j = j.split(".")[0]+"_trunc.wav"
#             flag = 2
#         if flag == 0:
#             continue
#         f.write("file \'{}\'\n".format(j))
#         if flag == 2:
#             break
    
#     f.close()

# %% [markdown]
# ## Steps done via code in the below cell
# - open anaconda prompt
# - Enter the following commands:
#     - For video concatenation:
#         - ```conda activate daq```
#         - ```ffmpeg -f concat -safe 0 -i {path_to_text_file} -c copy {path_to_output_file}```
#
#             eg: ```ffmpeg -f concat -safe 0 -i D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\video_e3v83b3.txt -c copy D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\e3v83b3_ffmpeg.mp4```
#     - For NIDAQ concatenation:
#         - - ```conda activate daq```
#         - ```ffmpeg -f concat -safe 0 -i {path_to_text_file} -c copy {path_to_output_file}```
#
#             eg: ```ffmpeg -f concat -safe 0 -i D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\channel_0.txt -c copy D:\big_setup\experiment_9\concatenated_data_cam_mic_sync\channel_0_ffmpeg.wav```

# %%
no_audio_files = int(len(glob.glob(path_concat + "*channel_*.txt"))/no_channels)
no_video_files = int(len(glob.glob(path_concat + "*video_*.txt"))/len(camera_names))

# %%
timestamp_record_data = cam_clk_data.iloc[timestamp_idx]
time_starts = []
time_ends = []
column_names = [i for i in timestamp_record_data.columns if i.endswith("file_name") and not(i.startswith('clk'))]

starting_timestamp = datetime.strptime(timestamp_record_data[column_names[0]][0].split('\\')[-1].split('-')[1], '%Y%m%dT%H%M%S')

# for camera_file in column_names:
#     for file_name in timestamp_record_data[camera_file]:
#         time_starts.append(datetime.strptime(file_name.split('\\')[-1].split('-')[1], '%Y%m%dT%H%M%S'))
#         time_ends.append(time_starts[-1] + timedelta(minutes=file_length/60))

# %%
# if no_audio_files != no_video_files:
#     raise Exception("Number of audio and video files don't match")
# else:
matched_csv = []
timestamp_write = starting_timestamp
f = open(path_final+"README.txt", 'w')
f.write("The files that are synced are as follows:\n")
f.write("Video file names - corresponding audio file names - timestamp range of file \n")
for i in range(no_audio_files):
    temp_0 = []
    temp_1 = []
    temp_2 = [timestamp_write.strftime("%Y-%m-%d %H:%M:%S"),(timestamp_write + timedelta(minutes=file_length/60)).strftime("%Y-%m-%d %H:%M:%S")]
    timestamp_write += timedelta(minutes=file_length/60)
    for j in range(no_channels):
        var_1 = "%03d"%(i)
        var_2 = "%02d"%(j)
        temp_0.append(f"channel_{var_2}_file_{var_1}")
    for j in camera_names:
        var_1 = "%03d"%(i)
        temp_1.append(f"video_{j}_{var_1}")
    f.write(f"[{', '.join(temp_1)}] - [{', '.join(temp_0)}] - [{', '.join(temp_2)}]\n")
    matched_csv.append([temp_1,temp_0,temp_2])
pd.DataFrame(matched_csv,columns=["video","audio","timestamp"]).to_csv(path_final+"sync.csv", index = False)
f.close()

# %%
filename_txt = path_concat + "*.txt"
txt_files = glob.glob(filename_txt)
video_files = []
audio_files = []

for file in txt_files:
    name = file.split('\\')[-1].split(".")[0]
    full_path_txt = path_concat+name+".txt"
    full_path_txt = full_path_txt.replace("/","\\")
    if name[0] == "c":
        full_path_wav = path_final+name+".wav"
        full_path_wav = full_path_wav.replace("/","\\")
        # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_wav}
        # -rf64 auto
    else:
        full_path_mp4 = path_final+name+".mp4"
        full_path_mp4 = full_path_mp4.replace("/","\\")
        # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy {full_path_mp4}
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_000.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_000.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed= 931x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_001.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_001.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed= 944x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_002.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_002.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed= 956x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_003.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_003.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.98 bitrate=4000.1kbits/s speed= 871x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_004.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_004.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   35328kB time=00:01:12.35 bitrate=3999.9kbits/s speed= 145x
# size=   87808kB time=00:02:59.97 bitrate=3996.9kbits/s speed= 131x
# size=  101120kB time=00:03:27.23 bitrate=3997.3kbits/s speed= 111x
# size=  137728kB time=00:04:42.20 bitrate=3998.0kbits/s speed= 119x
# size=  154880kB time=00:05:17.59 bitrate=3994.9kbits/s speed= 109x
# size=  175780kB time=00:05:59.99 bitrate=4000.1kbits/s speed= 119x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_005.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_005.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.1kbits/s speed= 948x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_006.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_006.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed= 949x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_007.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_007.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed= 933x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_008.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_008.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed= 945x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_009.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_009.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   18432kB time=00:00:37.90 bitrate=3983.7kbits/s speed=75.3x
# size=   32000kB time=00:01:05.69 bitrate=3990.6kbits/s speed=63.1x
# size=   92160kB time=00:03:08.75 bitrate=3999.9kbits/s speed= 122x
# size=  137728kB time=00:04:42.22 bitrate=3997.8kbits/s speed= 135x
# size=  152064kB time=00:05:11.84 bitrate=3994.7kbits/s speed= 120x
# size=  160256kB time=00:05:28.35 bitrate=3998.1kbits/s speed=64.9x
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed=68.1x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_010.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_010.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.98 bitrate=4000.1kbits/s speed= 953x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_011.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_011.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.1kbits/s speed= 874x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_012.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_012.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.1kbits/s speed= 898x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_013.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_013.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.1kbits/s speed= 828x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_014.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_014.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   17408kB time=00:00:36.08 bitrate=3952.3kbits/s speed=70.8x
# size=   17920kB time=00:00:37.13 bitrate=3953.6kbits/s speed=12.6x
# size=   18176kB time=00:00:37.39 bitrate=3982.0kbits/s speed=9.96x
# size=   32768kB time=00:01:07.11 bitrate=3999.7kbits/s speed=15.8x
# size=   69888kB time=00:02:23.56 bitrate=3988.0kbits/s speed=30.2x
# size=   97280kB time=00:03:19.65 bitrate=3991.4kbits/s speed=  38x
# size=  126208kB time=00:04:18.90 bitrate=3993.3kbits/s speed=44.1x
# size=  150528kB time=00:05:08.44 bitrate=3997.8kbits/s speed=36.8x
# size=  153856kB time=00:05:15.26 bitrate=3997.9kbits/s speed=35.5x
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed=38.7x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_015.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_015.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed= 910x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_016.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_016.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.0kbits/s speed= 885x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_017.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_017.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.98 bitrate=4000.1kbits/s speed= 897x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_018.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_018.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  175780kB time=00:05:59.99 bitrate=4000.1kbits/s speed= 909x
# video:0kB audio:175780kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000063%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_00_file_019.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_00_file_019.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   51758kB time=00:01:45.99 bitrate=4000.0kbits/s speed= 908x
# video:0kB audio:51757kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000215%
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, concat, from 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\temp\channel_01_file_000.txt':
#   Duration: N/A, start: 0.000000, bitrate: 4000 kb/s
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Output #0, wav, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\channel_01_file_000.wav':
#   Metadata:
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 125000 Hz, mono, flt, 4000 kb/s
# Stream mapping:
# ...
# Output #0, mp4, to 'D:\big_setup\experiment_547\concatenated_data_cam_mic_sync\video_center_018.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv420p, 1600x1200, q=2-31, 57090 kb/s, 30 fps, 30 tbr, 1000k tbn, 1000k tbc
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=    8 fps=3.3 q=-1.0 size=    2560kB time=00:00:00.23 bitrate=89880.1kbits/s speed=0.0974x
# frame=   18 fps=6.2 q=-1.0 size=    4608kB time=00:00:00.56 bitrate=66616.6kbits/s speed=0.194x
# frame=   59 fps= 17 q=-1.0 size=   13824kB time=00:00:01.93 bitrate=58576.4kbits/s speed=0.561x
# frame=  111 fps= 28 q=-1.0 size=   26112kB time=00:00:03.66 bitrate=58339.6kbits/s speed=0.914x
# frame=  222 fps= 49 q=-1.0 size=   51712kB time=00:00:07.36 bitrate=57506.2kbits/s speed=1.62x
# frame=  324 fps= 64 q=-1.0 size=   75520kB time=00:00:10.76 bitrate=57461.3kbits/s speed=2.13x
# frame=  419 fps= 75 q=-1.0 size=   97280kB time=00:00:13.93 bitrate=57195.6kbits/s speed=2.48x
# frame=  458 fps= 63 q=-1.0 size=  106752kB time=00:00:15.23 bitrate=57408.4kbits/s speed=2.11x
# frame=  546 fps= 70 q=-1.0 size=  127232kB time=00:00:18.16 bitrate=57374.1kbits/s speed=2.31x
# frame=  565 fps= 67 q=-1.0 size=  131328kB time=00:00:18.79 bitrate=57226.1kbits/s speed=2.23x
# frame=  625 fps= 70 q=-1.0 size=  145408kB time=00:00:20.79 bitrate=57269.0kbits/s speed=2.33x
# frame=  684 fps= 72 q=-1.0 size=  158976kB time=00:00:22.76 bitrate=57204.0kbits/s speed=2.41x
# frame=  770 fps= 77 q=-1.0 size=  179200kB time=00:00:25.63 bitrate=57270.0kbits/s speed=2.57x
# frame=  847 fps= 80 q=-1.0 size=  197120kB time=00:00:28.19 bitrate=57263.2kbits/s speed=2.67x
# frame=  947 fps= 85 q=-1.0 size=  220160kB time=00:00:31.53 bitrate=57195.6kbits/s speed=2.85x
# frame= 1026 fps= 88 q=-1.0 size=  238848kB time=00:00:34.16 bitrate=57268.2kbits/s speed=2.93x
# frame= 1030 fps= 84 q=-1.0 size=  239872kB time=00:00:34.29 bitrate=57290.1kbits/s speed= 2.8x
# frame= 1102 fps= 86 q=-1.0 size=  256256kB time=00:00:36.69 bitrate=57200.8kbits/s speed=2.87x
# frame= 1182 fps= 89 q=-1.0 size=  274944kB time=00:00:39.36 bitrate=57215.0kbits/s speed=2.95x
# frame= 1301 fps= 94 q=-1.0 size=  302848kB time=00:00:43.33 bitrate=57252.8kbits/s speed=3.12x
# frame= 1384 fps= 96 q=-1.0 size=  321792kB time=00:00:46.09 bitrate=57183.2kbits/s speed=3.19x
# frame= 1535 fps=103 q=-1.0 size=  357120kB time=00:00:51.13 bitrate=57214.3kbits/s speed=3.42x
# frame= 1563 fps=101 q=-1.0 size=  363520kB time=00:00:52.06 bitrate=57195.6kbits/s speed=3.37x
# frame= 1647 fps=102 q=-1.0 size=  382720kB time=00:00:54.86 bitrate=57143.5kbits/s speed=3.41x
# frame= 1694 fps=100 q=-1.0 size=  393728kB time=00:00:56.43 bitrate=57155.1kbits/s speed=3.33x
# frame= 1753 fps= 95 q=-1.0 size=  407808kB time=00:00:58.39 bitrate=57205.4kbits/s speed=3.17x
# frame= 1886 fps=100 q=-1.0 size=  438272kB time=00:01:02.83 bitrate=57141.0kbits/s speed=3.32x
# frame= 1950 fps=100 q=-1.0 size=  452864kB time=00:01:04.96 bitrate=57104.7kbits/s speed=3.34x
# frame= 2002 fps=100 q=-1.0 size=  465664kB time=00:01:06.69 bitrate=57192.8kbits/s speed=3.34x
# frame= 2067 fps=101 q=-1.0 size=  480512kB time=00:01:08.86 bitrate=57159.6kbits/s speed=3.36x
# frame= 2182 fps=103 q=-1.0 size=  507136kB time=00:01:12.69 bitrate=57145.8kbits/s speed=3.45x
# frame= 2260 fps=104 q=-1.0 size=  525568kB time=00:01:15.29 bitrate=57177.9kbits/s speed=3.47x
# frame= 2323 fps=104 q=-1.0 size=  540160kB time=00:01:17.39 bitrate=57171.0kbits/s speed=3.48x
# frame= 2382 fps=105 q=-1.0 size=  553728kB time=00:01:19.36 bitrate=57154.8kbits/s speed=3.49x
# frame= 2387 fps= 99 q=-1.0 size=  554752kB time=00:01:19.53 bitrate=57140.5kbits/s speed=3.28x
# frame= 2431 fps= 98 q=-1.0 size=  564736kB time=00:01:20.99 bitrate=57115.6kbits/s speed=3.27x
# frame= 2538 fps=100 q=-1.0 size=  590080kB time=00:01:24.56 bitrate=57161.8kbits/s speed=3.32x
# frame= 2608 fps=100 q=-1.0 size=  605952kB time=00:01:26.89 bitrate=57123.2kbits/s speed=3.34x
# frame= 2653 fps=100 q=-1.0 size=  616704kB time=00:01:28.39 bitrate=57150.3kbits/s speed=3.33x
# frame= 2716 fps=100 q=-1.0 size=  631040kB time=00:01:30.49 bitrate=57121.9kbits/s speed=3.34x
# frame= 2821 fps=102 q=-1.0 size=  655360kB time=00:01:33.99 bitrate=57114.5kbits/s speed= 3.4x
# frame= 2950 fps=105 q=-1.0 size=  685568kB time=00:01:38.29 bitrate=57133.6kbits/s speed=3.49x
# frame= 2983 fps=103 q=-1.0 size=  692992kB time=00:01:39.39 bitrate=57113.2kbits/s speed=3.44x
# frame= 3049 fps=104 q=-1.0 size=  708352kB time=00:01:41.59 bitrate=57114.9kbits/s speed=3.46x
# frame= 3156 fps=106 q=-1.0 size=  733184kB time=00:01:45.16 bitrate=57112.2kbits/s speed=3.52x
# frame= 3221 fps=106 q=-1.0 size=  748288kB time=00:01:47.33 bitrate=57112.1kbits/s speed=3.53x
# frame= 3274 fps=105 q=-1.0 size=  760832kB time=00:01:49.09 bitrate=57129.2kbits/s speed=3.49x
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001baebd402c0] Auto-inserting h264_mp4toannexb bitstream filter
# frame= 3304 fps= 99 q=-1.0 size=  767744kB time=00:01:50.09 bitrate=57124.4kbits/s speed=3.31x
# frame= 3316 fps= 98 q=-1.0 size=  770560kB time=00:01:50.49 bitrate=57126.4kbits/s speed=3.26x
# frame= 3346 fps= 97 q=-1.0 size=  777472kB time=00:01:51.49 bitrate=57121.9kbits/s speed=3.23x
# frame= 3353 fps= 94 q=-1.0 size=  779008kB time=00:01:51.73 bitrate=57115.2kbits/s speed=3.14x
# frame= 3364 fps= 93 q=-1.0 size=  781568kB time=00:01:52.09 bitrate=57115.5kbits/s speed= 3.1x
# frame= 3407 fps= 93 q=-1.0 size=  791552kB time=00:01:53.53 bitrate=57114.8kbits/s speed= 3.1x
# frame= 3517 fps= 95 q=-1.0 size=  817152kB time=00:01:57.19 bitrate=57117.3kbits/s speed=3.16x
# frame= 3554 fps= 93 q=-1.0 size=  826112kB time=00:01:58.43 bitrate=57142.3kbits/s speed=3.11x
# frame= 3582 fps= 93 q=-1.0 size=  832512kB time=00:01:59.36 bitrate=57134.7kbits/s speed=3.09x
# frame= 3629 fps= 93 q=-1.0 size=  843008kB time=00:02:00.93 bitrate=57105.6kbits/s speed=3.09x
# frame= 3717 fps= 94 q=-1.0 size=  863488kB time=00:02:03.86 bitrate=57107.7kbits/s speed=3.12x
# frame= 3832 fps= 95 q=-1.0 size=  890368kB time=00:02:07.69 bitrate=57117.8kbits/s speed=3.18x
# frame= 3834 fps= 94 q=-1.0 size=  890880kB time=00:02:07.76 bitrate=57120.8kbits/s speed=3.13x
# frame= 3894 fps= 93 q=-1.0 size=  904704kB time=00:02:09.76 bitrate=57113.2kbits/s speed= 3.1x
# frame= 3972 fps= 94 q=-1.0 size=  922880kB time=00:02:12.36 bitrate=57116.2kbits/s speed=3.12x
# frame= 3996 fps= 92 q=-1.0 size=  928512kB time=00:02:13.16 bitrate=57119.6kbits/s speed=3.08x
# frame= 4026 fps= 91 q=-1.0 size=  935424kB time=00:02:14.16 bitrate=57115.9kbits/s speed=3.03x
# frame= 4133 fps= 92 q=-1.0 size=  959744kB time=00:02:17.73 bitrate=57083.3kbits/s speed=3.07x
# frame= 4210 fps= 93 q=-1.0 size=  977920kB time=00:02:20.29 bitrate=57100.3kbits/s speed= 3.1x
# frame= 4337 fps= 94 q=-1.0 size= 1007616kB time=00:02:24.53 bitrate=57111.0kbits/s speed=3.13x
# frame= 4339 fps= 93 q=-1.0 size= 1007872kB time=00:02:24.59 bitrate=57099.2kbits/s speed=3.09x
# frame= 4398 fps= 93 q=-1.0 size= 1021440kB time=00:02:26.56 bitrate=57091.4kbits/s speed= 3.1x
# frame= 4443 fps= 91 q=-1.0 size= 1031936kB time=00:02:28.06 bitrate=57093.7kbits/s speed=3.02x
# frame= 4522 fps= 91 q=-1.0 size= 1050112kB time=00:02:30.69 bitrate=57084.1kbits/s speed=3.04x
# frame= 4584 fps= 91 q=-1.0 size= 1064704kB time=00:02:32.76 bitrate=57094.4kbits/s speed=3.04x
# frame= 4684 fps= 92 q=-1.0 size= 1087744kB time=00:02:36.09 bitrate=57084.3kbits/s speed=3.08x
# frame= 4810 fps= 94 q=-1.0 size= 1116928kB time=00:02:40.29 bitrate=57080.1kbits/s speed=3.13x
# frame= 4925 fps= 95 q=-1.0 size= 1143296kB time=00:02:44.13 bitrate=57063.1kbits/s speed=3.17x
# frame= 5026 fps= 96 q=-1.0 size= 1166592kB time=00:02:47.49 bitrate=57055.5kbits/s speed=3.19x
# frame= 5085 fps= 96 q=-1.0 size= 1180672kB time=00:02:49.46 bitrate=57074.0kbits/s speed= 3.2x
# frame= 5145 fps= 96 q=-1.0 size= 1194496kB time=00:02:51.46 bitrate=57068.7kbits/s speed=3.21x
# frame= 5215 fps= 97 q=-1.0 size= 1210368kB time=00:02:53.79 bitrate=57050.7kbits/s speed=3.22x
# frame= 5305 fps= 97 q=-1.0 size= 1231360kB time=00:02:56.79 bitrate=57055.3kbits/s speed=3.24x
# frame= 5371 fps= 97 q=-1.0 size= 1246464kB time=00:02:58.99 bitrate=57045.3kbits/s speed=3.25x
# frame= 5474 fps= 98 q=-1.0 size= 1270528kB time=00:03:02.43 bitrate=57052.3kbits/s speed=3.28x
# frame= 5493 fps= 98 q=-1.0 size= 1274880kB time=00:03:03.06 bitrate=57049.7kbits/s speed=3.26x
# frame= 5514 fps= 97 q=-1.0 size= 1279744kB time=00:03:03.76 bitrate=57049.2kbits/s speed=3.24x
# frame= 5524 fps= 94 q=-1.0 size= 1282304kB time=00:03:04.09 bitrate=57059.8kbits/s speed=3.14x
# frame= 5543 fps= 94 q=-1.0 size= 1286400kB time=00:03:04.73 bitrate=57045.8kbits/s speed=3.12x
# frame= 5578 fps= 93 q=-1.0 size= 1294336kB time=00:03:05.89 bitrate=57037.6kbits/s speed=3.11x
# frame= 5646 fps= 94 q=-1.0 size= 1310208kB time=00:03:08.16 bitrate=57041.5kbits/s speed=3.12x
# frame= 5720 fps= 94 q=-1.0 size= 1327360kB time=00:03:10.63 bitrate=57040.5kbits/s speed=3.13x
# frame= 5792 fps= 94 q=-1.0 size= 1343488kB time=00:03:13.03 bitrate=57015.7kbits/s speed=3.15x
# frame= 5856 fps= 95 q=-1.0 size= 1359104kB time=00:03:15.16 bitrate=57048.0kbits/s speed=3.15x
# frame= 5941 fps= 95 q=-1.0 size= 1378304kB time=00:03:17.99 bitrate=57026.0kbits/s speed=3.17x
# frame= 5966 fps= 95 q=-1.0 size= 1384192kB time=00:03:18.83 bitrate=57029.6kbits/s speed=3.16x
# frame= 6113 fps= 96 q=-1.0 size= 1418496kB time=00:03:23.73 bitrate=57037.4kbits/s speed=3.21x
# frame= 6221 fps= 97 q=-1.0 size= 1443584kB time=00:03:27.33 bitrate=57038.3kbits/s speed=3.23x
# frame= 6328 fps= 98 q=-1.0 size= 1468160kB time=00:03:30.89 bitrate=57028.3kbits/s speed=3.26x
# frame= 6395 fps= 98 q=-1.0 size= 1484032kB time=00:03:33.13 bitrate=57040.8kbits/s speed=3.27x
# frame= 6454 fps= 98 q=-1.0 size= 1497600kB time=00:03:35.09 bitrate=57036.0kbits/s speed=3.27x
# frame= 6484 fps= 98 q=-1.0 size= 1504512kB time=00:03:36.09 bitrate=57034.1kbits/s speed=3.25x
# frame= 6604 fps= 99 q=-1.0 size= 1532416kB time=00:03:40.09 bitrate=57036.1kbits/s speed=3.29x
# frame= 6708 fps= 99 q=-1.0 size= 1556480kB time=00:03:43.56 bitrate=57033.5kbits/s speed=3.31x
# frame= 6804 fps=100 q=-1.0 size= 1578752kB time=00:03:46.76 bitrate=57033.3kbits/s speed=3.34x
# frame= 6818 fps= 99 q=-1.0 size= 1582336kB time=00:03:47.23 bitrate=57045.3kbits/s speed=3.29x
# frame= 6911 fps= 99 q=-1.0 size= 1603840kB time=00:03:50.33 bitrate=57042.4kbits/s speed=3.31x
# frame= 7012 fps=100 q=-1.0 size= 1626880kB time=00:03:53.69 bitrate=57028.3kbits/s speed=3.33x
# frame= 7090 fps=100 q=-1.0 size= 1645056kB time=00:03:56.29 bitrate=57030.9kbits/s speed=3.34x
# frame= 7190 fps=101 q=-1.0 size= 1667840kB time=00:03:59.63 bitrate=57016.5kbits/s speed=3.37x
# frame= 7283 fps=101 q=-1.0 size= 1689344kB time=00:04:02.73 bitrate=57014.1kbits/s speed=3.38x
# frame= 7339 fps=102 q=-1.0 size= 1702656kB time=00:04:04.59 bitrate=57024.8kbits/s speed=3.38x
# frame= 7424 fps=102 q=-1.0 size= 1722368kB time=00:04:07.43 bitrate=57024.5kbits/s speed= 3.4x
# frame= 7536 fps=103 q=-1.0 size= 1748224kB time=00:04:11.16 bitrate=57020.2kbits/s speed=3.42x
# frame= 7697 fps=104 q=-1.0 size= 1785600kB time=00:04:16.53 bitrate=57020.9kbits/s speed=3.47x
# frame= 7699 fps=102 q=-1.0 size= 1785856kB time=00:04:16.59 bitrate=57014.2kbits/s speed=3.42x
# frame= 7802 fps=103 q=-1.0 size= 1809408kB time=00:04:20.03 bitrate=57003.4kbits/s speed=3.44x
# frame= 7893 fps=104 q=-1.0 size= 1830656kB time=00:04:23.06 bitrate=57007.8kbits/s speed=3.45x
# frame= 7995 fps=104 q=-1.0 size= 1854208kB time=00:04:26.46 bitrate=57004.5kbits/s speed=3.47x
# frame= 8022 fps=104 q=-1.0 size= 1860352kB time=00:04:27.36 bitrate=57000.9kbits/s speed=3.46x
# frame= 8099 fps=104 q=-1.0 size= 1878272kB time=00:04:29.93 bitrate=57002.7kbits/s speed=3.47x
# frame= 8165 fps=104 q=-1.0 size= 1893888kB time=00:04:32.13 bitrate=57012.0kbits/s speed=3.47x
# frame= 8260 fps=105 q=-1.0 size= 1915648kB time=00:04:35.29 bitrate=57003.7kbits/s speed=3.49x
# frame= 8293 fps=104 q=-1.0 size= 1923328kB time=00:04:36.39 bitrate=57004.5kbits/s speed=3.47x
# frame= 8295 fps=103 q=-1.0 size= 1923840kB time=00:04:36.46 bitrate=57005.9kbits/s speed=3.43x
# frame= 8371 fps=103 q=-1.0 size= 1941248kB time=00:04:38.99 bitrate=56999.4kbits/s speed=3.43x
# frame= 8430 fps=103 q=-1.0 size= 1955072kB time=00:04:40.96 bitrate=57003.5kbits/s speed=3.43x
# frame= 8521 fps=104 q=-1.0 size= 1975808kB time=00:04:43.99 bitrate=56992.8kbits/s speed=3.45x
# frame= 8645 fps=104 q=-1.0 size= 2004992kB time=00:04:48.13 bitrate=57005.0kbits/s speed=3.48x
# frame= 8732 fps=105 q=-1.0 size= 2024448kB time=00:04:51.03 bitrate=56984.6kbits/s speed=3.49x
# frame= 8804 fps=105 q=-1.0 size= 2041856kB time=00:04:53.43 bitrate=57004.5kbits/s speed=3.49x
# frame= 8866 fps=105 q=-1.0 size= 2056192kB time=00:04:55.49 bitrate=57003.3kbits/s speed=3.49x
# frame= 8929 fps=105 q=-1.0 size= 2070528kB time=00:04:57.59 bitrate=56995.7kbits/s speed= 3.5x
# frame= 8959 fps=104 q=-1.0 size= 2077440kB time=00:04:58.59 bitrate=56994.4kbits/s speed=3.46x
# frame= 9034 fps=104 q=-1.0 size= 2094848kB time=00:05:01.09 bitrate=56994.8kbits/s speed=3.47x
# frame= 9125 fps=105 q=-1.0 size= 2116864kB time=00:05:04.13 bitrate=57019.4kbits/s speed=3.48x
# frame= 9170 fps=104 q=-1.0 size= 2127360kB time=00:05:05.63 bitrate=57020.9kbits/s speed=3.48x
# frame= 9244 fps=105 q=-1.0 size= 2144768kB time=00:05:08.09 bitrate=57027.2kbits/s speed=3.49x
# frame= 9257 fps=104 q=-1.0 size= 2147840kB time=00:05:08.53 bitrate=57028.7kbits/s speed=3.47x
# frame= 9400 fps=105 q=-1.0 size= 2181120kB time=00:05:13.29 bitrate=57031.2kbits/s speed= 3.5x
# frame= 9495 fps=105 q=-1.0 size= 2203136kB time=00:05:16.46 bitrate=57030.5kbits/s speed=3.51x
# frame= 9566 fps=106 q=-1.0 size= 2219520kB time=00:05:18.83 bitrate=57028.1kbits/s speed=3.52x
# frame= 9699 fps=106 q=-1.0 size= 2250496kB time=00:05:23.26 bitrate=57031.0kbits/s speed=3.54x
# frame= 9789 fps=107 q=-1.0 size= 2271232kB time=00:05:26.26 bitrate=57027.3kbits/s speed=3.56x
# frame= 9870 fps=107 q=-1.0 size= 2289920kB time=00:05:28.96 bitrate=57024.6kbits/s speed=3.57x
# frame=10025 fps=108 q=-1.0 size= 2326784kB time=00:05:34.13 bitrate=57046.6kbits/s speed= 3.6x
# frame=10125 fps=108 q=-1.0 size= 2350592kB time=00:05:37.46 bitrate=57061.1kbits/s speed=3.61x
# frame=10141 fps=108 q=-1.0 size= 2354176kB time=00:05:37.99 bitrate=57057.9kbits/s speed=3.59x
# frame=10163 fps=107 q=-1.0 size= 2359552kB time=00:05:38.73 bitrate=57064.4kbits/s speed=3.58x
# frame=10179 fps=107 q=-1.0 size= 2363648kB time=00:05:39.26 bitrate=57073.6kbits/s speed=3.57x
# frame=10260 fps=107 q=-1.0 size= 2382080kB time=00:05:41.96 bitrate=57064.5kbits/s speed=3.58x
# frame=10303 fps=106 q=-1.0 size= 2393088kB time=00:05:43.39 bitrate=57089.0kbits/s speed=3.54x
# frame=10372 fps=106 q=-1.0 size= 2409216kB time=00:05:45.69 bitrate=57091.3kbits/s speed=3.54x
# frame=10482 fps=107 q=-1.0 size= 2435584kB time=00:05:49.36 bitrate=57110.4kbits/s speed=3.56x
# frame=10624 fps=108 q=-1.0 size= 2469120kB time=00:05:54.09 bitrate=57122.9kbits/s speed=3.59x
# frame=10711 fps=108 q=-1.0 size= 2489344kB time=00:05:56.99 bitrate=57122.9kbits/s speed= 3.6x
# frame=10791 fps=108 q=-1.0 size= 2508288kB time=00:05:59.66 bitrate=57130.9kbits/s speed=3.61x
# frame=10801 fps=108 q=-1.0 Lsize= 2510514kB time=00:05:59.99 bitrate=57128.7kbits/s speed=3.61x
# video:2510449kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002623%

# %% [markdown]
# ## Testing sync

# %%
'''import warnings
import math'''

# %%
'''# Redoing the files that didn't get written
channel_txt_search = path_concat + "*channel_*.txt"
video_txt_search = path_concat + "*video_*.txt"

channel_txt_filenames = glob.glob(channel_txt_search)
video_txt_filenames = glob.glob(video_txt_search)

channel_txt_filenames.sort(key=natural_keys)
video_txt_filenames.sort(key=natural_keys)

upper_no_audio_files = math.ceil(len(channel_txt_filenames)/no_channels)
upper_no_video_files = math.ceil(len(video_txt_filenames)/len(camera_names))
print(f"Number of audio files: {upper_no_audio_files}")
print(f"Number of video files: {upper_no_video_files}")



# For channel txt files
prev_ch_idx_nos = 0
prev_ch_nos = 0

# if not(len(channel_txt_filenames)%no_channels > (no_channels-1)):
#     raise Exception(f"Channel txt files are missing re-run code")


# First test - no of indices per channel is the same
if len(channel_txt_filenames)%no_channels > 0:
    warnings.warn("The length of the audio channel text files do not match")
    print("Testing each channels txt files")

    counter = 0

    for name in channel_txt_filenames:
        vals = name.split("\\")[-1].split('_')
        channel_ = int(vals[1])
        index_ = int(vals[2].split(".")[0])

        if channel_ - prev_ch_nos == 1:
                prev_ch_nos = channel_
                prev_ch_idx_nos = 0
                counter = 0
        else:
            raise Exception(f"Missing channel {prev_ch_nos+1} - need to rerun code")

        if channel_ - prev_ch_nos == 0:
            if counter == 0:
                counter = 1
                if  index_ != prev_ch_idx_nos:
                    raise Exception(f"Missing channel {prev_ch_nos} index {prev_ch_idx_nos} - need to rerun code")
                
            if prev_ch_idx_nos - index_ > 1:
                    no_missing_files =  prev_ch_idx_nos - index_
                    raise Exception(f"There are {no_missing_files} text files in channel {channel_} between {prev_ch_idx_nos} and {index_} - need to rerun code") 

            
            prev_ch_idx_nos+=1

        
        temp = file.split('\\')[-1].split(".")[0]
        full_path_txt = path_concat+temp+".txt"
        full_path_txt = full_path_txt.replace("/","\\")
        full_path_wav = path_final+name+".wav"
        full_path_wav = full_path_wav.replace("/","\\")
        if  os.path.exists(full_path_wav):
            continue
        else:
            warnings.warn(f"File {temp}.wav doesn't exist - trying to rerun")
            # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_wav}
            if not(os.path.exists(full_path_wav)):
                   raise Exception("Unable to create file from txt, re run concat")
        
    

# For video txt files 
prev_vid_idx_nos = 0
camera_names.sort(key=natural_keys)
prev_vid_name = camera_names[0]


# if not(len(video_txt_filenames)/len(camera_names) > len(camera_names)-1):
#     raise Exception(f"Video txt files are missing re-run code")

# First test - no of indices per video is the same
if len(video_txt_filenames)%len(camera_names) > 0:
    warnings.warn("The length of the video text files per camera do not match")
    print("Testing each cameras txt files")

    counter = 0

    for name in video_txt_filenames:

        vals = name.split("\\")[-1].split('_')
        video_ = vals[1]
        index_ = int(vals[2].split(".")[0])

        if video_ != prev_vid_name:
                prev_vid_name = video_
                prev_vid_idx_nos = 0
                counter = 0

        if video_ == prev_vid_name:
            if counter == 0:
                counter = 1
                if  index_ != prev_vid_idx_nos:
                    raise Exception(f"Missing video {prev_vid_name} index {prev_vid_idx_nos}")
                
            if prev_vid_idx_nos - index_ > 1:
                    no_missing_files =  prev_vid_idx_nos - index_
                    raise Exception(f"There are {no_missing_files} text files in channel {video_} between {prev_vid_idx_nos} and {index_}") 

            
            prev_ch_idx_nos+=1


        temp = file.split('\\')[-1].split(".")[0]
        full_path_txt = path_concat+temp+".txt"
        full_path_txt = full_path_txt.replace("/","\\")

        full_path_mp4 = path_final+name+".mp4"
        full_path_mp4 = full_path_mp4.replace("/","\\")

        if  os.path.exists(full_path_mp4):
            continue
        else:
            warnings.warn(f"File {temp}.mp4 doesn't exist - trying to rerun")
            # !ffmpeg -f concat -safe 0 -i {full_path_txt} -c copy  {full_path_mp4}
            if not(os.path.exists(full_path_wav)):
                   raise Exception("Unable to create file from txt, re run concat")'''
# Out:
#   Cell In[160], line 65
#     if not(os.path.exists(full_path_wav):
#                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# old camera frame rate - 1/0.03338542
#
# new camera frame rate -
